# %%
include("/Users/fernandopenaranda/Dropbox/Sync/ShiftCurrents_in_tBLG/src/ShiftCurrents_in_tBLG.jl") # continuum
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/HF_Optics.jl")
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/sublattice_masses.jl")
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_compute.jl")
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_linear_conductivity.jl")
# Out:
# k_in_plane_bindependent_conductivity_integrand (generic function with 1 method)

# %%
using CairoMakie
CairoMakie.disable_mime!("svg", "pdf", "text/html")

# %% [markdown]
# #### Plotters

# %%
function BZdecorations!(p, ax)
    G1, G2 = bravais_vectors(p);     
    K1 =  κ(G1, G2)
    K2 =  κ(G2, G1)
    scatter!(ax, K1[1], K1[2], color = :red, marker = :x, markersize = 10)
    scatter!(ax, K2[1], K2[2], color = :blue, marker = :x, markersize = 10)
    scatter!(ax, K1[1]-G1[1], K1[2]-G1[2], color = :red, marker = :x, markersize = 10)
    scatter!(ax, K1[1]-G2[1]-G1[1], K1[2]-G2[2]-G1[2], color = :red, marker = :x, markersize = 10)
    scatter!(ax, K1[1]-G2[1], K1[2]-G2[2], color = :red, marker = :x, markersize = 10)
    scatter!(ax, K2[1]-G2[1], K2[2]-G2[2], color = :blue, marker = :x, markersize = 10)
    scatter!(ax, K2[1]-G1[1]-G2[1], K2[2]-G1[2]-G2[2], color = :blue, marker = :x, markersize = 10)
    scatter!(ax, [0, G1[1],G2[1],-G1[1],-G2[1],G1[1]+G2[1],-G1[1]-G2[1]], 
             [0,G1[2],G2[2],-G1[2],-G2[2],G1[2]+G2[2],-G1[2]-G2[2]], 
            color = :black, marker = :x, markersize = 10)
    lines!(ax, [0, G1[1], G1[1]+G2[1], G2[1] , 0], 
             [0, G1[2],  G1[2]+G2[2], G2[2] , 0], 
            color = :black, linestyle = :dash)
end
# Out:
# BZdecorations! (generic function with 1 method)

# %% [markdown]
# ### Presets

# %% [markdown]
# Note vp and v are multiplied by a0 in the HF presets, this is beacause k is divided by a0 in the model description.
# λ has units (is artificially multiplied by a0) ,the real value has to be divided by a0.
# Note that in hf_velocities we do not have to change anything.

# %% [markdown]
# #### Presets both continuum and Heavy fermion model

# %%
pBM = ParamsBM(paramsBM(1.05, 3,  1), mass = .0);
p = ParamsHF(paramsHF(1.05, 1,  1),
μ = 0,
nf = 1,
λ = 120,
M = 3.697,
v = -4.303e3*a0,
vp = 1.622e3*a0,
γ = -20,
layerz = 0,
sigmaz = 0.,
sigmazlayerz = 0,
U1 = 0,
U2 = 0,   
J = 0,
VP =true,
twovalleystwospins= true);

# %% [markdown]
# ### Bands

# %% [markdown]
# ##### Non interacting Bands: Heavy Fermion model

# %%
with_theme(CairoMakie=(px_per_unit = 2.0,)) do
    fig1 = Figure(); 
    ax1 = Axis(fig1[1,1], ylabel = L"$\text{E [meV]}$") ;
    plotmybands!(ax1, real.(bands(ParamsHF(p, μ = 0, sigmaz = 0), 0 .* [1,0,1,0,1,0,1,0], 101)),
    ylimits = [-75,75], color = :black); 
    fig1
end

# %%
of = diagm(0.5.*ones(8)) 
of = diagm([1,0,1,0,1,0,1,0]) 
μ = 0
#hf_plotbands(p, of, kpoints = 101, res = (1.5*600,1.5*400))
hf_plotbands(ParamsHF(p, μ = μ), of, kpoints = 101, res = (600,400))

# %% [markdown]
# #### Bands in the continuum

# %%
with_theme(CairoMakie=(px_per_unit = 5.0,)) do
    fig1 = Figure(); 
    ax1 = Axis(fig1[1,1], ylabel = L"$\text{E [meV]}$") ;
    compute_bands_continuum!(p, pBM, ax1, ylimits = [-50,50])
    fig1
end

# %%
with_theme(CairoMakie=(px_per_unit = 5.0,)) do
    fig1 = Figure(); 
    ax1 = Axis(fig1[1,1], ylabel = L"$\text{E [meV]}$") ;
    plotmybands!(ax1, real.(bands(ParamsHF(p, μ = 0, sigmaz = 0), ones(8), 101)),
        ylimits = [-50,50], color = :black); 
    compute_bands_continuum!(p, pBM, ax1, ylimits = [-50,50]);
    fig1
end

# %% [markdown]
# #### Self-consistent bands Heavy Fermion

# %%
config = SelfConsistency_config_random(1e-6, 4, 1, 1, 200)
filling = -2.5
sof, sμ, se = guided_sweep(:β, p, config, [filling])
sd = Self_consistent_data(sof, sμ, se, filling) # raw solution
svp, sqah = generate_vp_aqh_solutions(sd)
# Out:
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.1056, 0.0959, 0.1682, 0.124, 0.1347, 0.0666, 0.1877, 0.3656]
#  2.. It: 2 with Of: [0.1844, 0.1831, 0.2566, 0.2347, 0.1883, 0.1792, 0.3291, 0.8246]
#  3.. It: 3 with Of: [0.1044, 0.1043, 0.1513, 0.1427, 0.1045, 0.1042, 0.6841, 0.921]
#  4.. It: 4 with Of: [0.104, 0.104, 0.105, 0.1047, 0.104, 0.104, 0.7444, 0.8822]
# energy: -13122.979282131979
#  TIME: 101505 milliseconds
# Energy without penalities:-13122.979282131979
# (Self_consistent_data([[0.7443899694711797, 0.8821804872125907, 0.10396515690425956, 0.10395826892100103, 0.10498368507135827, 0.10473976729049223, 0.10396221978911385, 0.10396123470016812]], Any[-16.516909984679614], Any[-13122.979282131979], -2.5), Self_consistent_data([[0.7443899694711797, 0.8821804872125907, 0.10396515690425956, 0.10395826892100103, 0.10498368507135827, 0.10473976729049223, 0.10396221978911385, 0.10396123470016812]], Any[-16.516909984679614], Any[-13122.979282131979], -2.5))

# %%
Generate the valley polarized and quantum anomalous hall degen density matrices.

# %% [markdown]
# Self consistent Plots

# %%
hf_plotbands(ParamsHF(p, μ = svp.mus[1]), diagm(sqah.ofmats[1]), kpoints = 101, res = (1.5*600,1.5*400), ylims = [-15,15])
# hf_plotbands(ParamsHF(p, μ = -2), diagm([1,1,1,1,0,0,0,0]), kpoints = 101, res = (1.5*600,1.5*400), ylims = [-15,15])

# %% [markdown]
# ### Sublattice masses in the two models:

# %%
fig = two_plots_sublattice(ParamsHF(p, γ = -24.75,λ = 92, v= -a0*4.303e3, vp =  a0*1.622e3), pBM);
fig

# %% [markdown]
# ### In-plane Berry

# %%
Summed over all states at the fermi level, they might be degenerate leading to cancellations

# %%
# Define number of grid points
# RUN Self-consistent bands Heavy Fermion section
integrand(q) = k_inplaneberry(:x, ParamsHF(p, μ = sd.mus[1]), q, diagm(sd.ofmats[1]); T = 0.1)
M, xmin, xmax = int_boundaries(p)
a = [-xmax[1], xmin[2]];
b = [xmax[1], xmax[2]];

n = 50  # resolution (100x100 grid)
# Generate grid points
x = range(a[1], b[1], length=n)
y = range(a[2], b[2], length=n)


# Evaluate f on the grid
Zb = [integrand([xi, yi]) for xi in x, yi in y];  # notice: [row, column] ordering

# %%
# Create the density plot
vis = 250
fig = Figure(size=(1.23*600,600))
ax = Axis(fig[1, 1], xlabel="kx", ylabel="ky", title="LMC")
# heatmap!(ax, x, y, Z, colormap=:redsblues)#, colorrange=(-1, 1.0).*vis)
cmap = cgrad([:red, :white, :blue])
hm = heatmap!(ax, x, y, real(Zb), colormap=cmap, colorrange=(-1, 1.0).*vis)
BZdecorations!(p, ax)
# Colorbar(fig[1,2], ax)  # Add a colorbar
cb = Colorbar(fig[1, 2], hm)
xlims!(ax, a[1]-ϵ, b[1]+ϵ)
ylims!(ax, a[2]-ϵ, b[2]+ϵ)
fig

# %% [markdown]
# #### In plane berry along the x direction for the eigenvalue l \in 1:8 at the fermi level

# %%
# Define number of grid points
# RUN Self-consistent bands Heavy Fermion section
l = 3
integrand(q) = k_inplaneberry(:x, ParamsHF(p, μ = sd.mus[1]), q, diagm(sd.ofmats[1]), l; T = 0.1)
M, xmin, xmax = int_boundaries(p)
a = [-xmax[1], xmin[2]];
b = [xmax[1], xmax[2]];

n = 100  # resolution (100x100 grid)
# Generate grid points
x = range(a[1], b[1], length=n)
y = range(a[2], b[2], length=n)


# Evaluate f on the grid
Zb = [integrand([xi, yi]) for xi in x, yi in y];  # notice: [row, column] ordering

# %%
# Create the density plot
vis = 250
fig = Figure(size=(1.23*600,600))
ax = Axis(fig[1, 1], xlabel="kx", ylabel="ky", title="In-plane Berry [Å²], single flat-band")
# heatmap!(ax, x, y, Z, colormap=:redsblues)#, colorrange=(-1, 1.0).*vis)
cmap = cgrad([:red, :white, :blue])
hm = heatmap!(ax, x, y, real(Zb), colormap=cmap)#, colorrange=(-1, 1.0).*vis)
BZdecorations!(p, ax)
# Colorbar(fig[1,2], ax)  # Add a colorbar
cb = Colorbar(fig[1, 2], hm)
xlims!(ax, a[1]-ϵ, b[1]+ϵ)
ylims!(ax, a[2]-ϵ, b[2]+ϵ)
fig

# %% [markdown]
# ### Magneto Conductivity

# %% [markdown]
# #### Integrand

# %% [markdown]
# Units:
#
# velocity operators are in meV A so they have to be divided by hbar
# \Delta has the appropiate units
# momentum has the correct units L^-2
# Nota creo que solo con \xi estamos para rz pero tenemos que multiplicarlo por a0 para darle las unidades.
#
# Las unidades tras integrar de la magnetoconductividad son e^2/\hbar 1/Tesla

# %% [markdown]
# ### Tests custom

# %%
pcustom = ParamsHF(paramsHF(1.05, 1,  1),
μ = 0,
nf = 1,
λ = 120,
M = 2*3.697,
v = -4.303e3*a0,
vp =1.622e3*a0,
γ = -40,
sigmaz = 0,
sigmazlayerz = 0,
U1 = 0,
U2 = 0,   
J = 0,
VP =true,
twovalleystwospins= true);
G1, G2 = bravais_vectors(ParamsHF(pcustom, ν = 1));  
K1 =  κ(G1, G2)
K2 =  κ(G2, G1)
M = m(G1, G2)

ofmts = diagm([0,0,0,0,0,0,0,0].*0.5);
mu = -15
# Out:
# -15

# %%
kvects = [K1, -K1, [0.,0], K2];#, M + [0,norm(M)/2],-M-[0,norm(M)/2], [0.,0.]]#, -M, [0.,0.], M, K2, -K2]
kv = kvects[1];

# %%
hf_plotbands(ParamsHF(pcustom, μ =mu), ofmts, kpoints = 101, res = (600,400), ylims = [-15,15])

# %% [markdown]
# ##### In-plane Berry complicated plots

# %%
fig = Figure(size = (800, 400)); ax = Axis(fig[1,1], xlabel = "E (meV)", ylabel = "Ωx (Å²)");
h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kvects[1], ofmts);
ϵs, ψs = eigen(Matrix(h));

for kvect in kvects
    rn = (rand() * (0.04 + 0.04) - 0.04) 
    omegas = berryinplane(pcustom, mu, ofmts, kvect)
    lines!(ax, ϵs, omegas, alpha = 1, linewidth = 3, label = "$(round.(kvect, digits = 2))");
    scatter!(ax, ϵs, omegas .+ rn)
end
xlims!(ax, -40,40)
ylims!(ax, -1, 1)
axislegend(ax, orientation = :horizontal, position= :ct)
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
fig = Figure(size = (800, 400)); ax = Axis(fig[1,1], xlabel = "E (meV)", ylabel = "Rz (Å)");
h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kvects[1], ofmts);
ϵs, ψs = eigen(Matrix(h));

for kvect in kvects
    rn = rand() * (0.08 + 0.08) - 0.08
    rzvals = real.(diagrz(pcustom, mu, ofmts, kvect))
    lines!(ax, ϵs, rzvals, alpha = 1, linewidth = 3, label = "$(round.(kvect, digits = 2))");
    scatter!(ax, ϵs, rzvals .+ rn);
end
xlims!(ax, -40,40)
ylims!(ax, -5, 5)
axislegend(ax, orientation = :horizontal, position= :ct)
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
function berryinplane(pcustom, mu, ofmts, kvect)
    h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kvect, ofmts)
    ϵs, ψs = eigen(Matrix(h))
    dhx = dhf_hamiltonian(ParamsHF(pcustom, μ = mu), :x, ofmts)
    # dhy = dhf_hamiltonian(ParamsHF(pcustom, μ = mu), :y, ofmts);
    rzmat = rz(ψs, ParamsHF(pcustom, μ = mu), kvect, ofmts) * a0;
    rx = r(ϵs, ψs, dhx) 
    # ry = r(ϵs, ψs, dhy)
    # omegas=Ωin(:x, sign.(rzmat) .* rzmat, rzmat)
    omegas=Ωin(:x, rx, rzmat)
    # omegas= Ωin(:x,0I, rzmat)
    return omegas
end
# Out:
# berryinplane (generic function with 1 method)

# %% [markdown]
# #### In§-plane Berry complicated plots

# %%
fig = Figure(); ax = Axis(fig[1,1], xlabel = "Ωx_n [Å^²]", title = "Histogram of Ωx at k = $(round.(kv, digits = 2))")
rzvals = berryinplane(pcustom, mu, ofmts, kv)
hist!(ax, rzvals, bins = 100)
# xlims!(ax, -3,3) 
ylims!(ax, 0,9)
fig

# %%
fig = Figure(); ax = Axis(fig[1,1], xlabel = "Ωx_n [Å^²]", title = "Histogram of Ωx at different k")
for kv in kvects
    rzvals = [k_inplaneberry(:x, ParamsHF(pcustom, μ = mu), kv, ofmts, it; T = 10) for it in 1:8]
    hist!(ax, rzvals, bins = 1, width = 0.01, label = "k = $(round.(kv, digits = 2))")
end
# xlims!(ax, -2*maximum(abs.(rzvals)),2maximum(abs.(rzvals)))
ylims!(ax, -2,9)
axislegend(ax, position = :cb, orientation = :horizontal)
 fig

# %% [markdown]
# ### Rz, Berry maps

# %%
function funcmaps(p, func, n = 100)
    M, xmin, xmax = int_boundaries(p)
    a = [-xmax[1], xmin[2]];
    b = [xmax[1], xmax[2]];
    x = range(a[1], b[1], length=n)
    y = range(a[2], b[2], length=n)
    Zb = [func([xi, yi]) for xi in x, yi in y]
    return Zb
end   # notice: [row, column] ordering


# Create the density plot
function plotmap(pcustom, Zb, title = "In-plane Berry [Å²], single flat-band", n = 100; colormap = cgrad([:red, :white, :blue]), zrange = nothing)
    M, xmin, xmax = int_boundaries(p)
    a = [-xmax[1], xmin[2]];
    b = [xmax[1], xmax[2]];
    x = range(a[1], b[1], length=n)
    y = range(a[2], b[2], length=n)
    vis = 250
    fig = Figure(size=(1.23*600,600))
    ax = Axis(fig[1, 1], xlabel="kx", ylabel="ky", title=title)
# heatmap!(ax, x, y, Z, colormap=:redsblues)#, colorrange=(-1, 1.0).*vis)
    # cmap = cgrad([:red, :white, :blue])
 if zrange === nothing
    hm = heatmap!(ax, x, y, Zb, colormap=colormap)
    else
    hm = heatmap!(ax, x, y, Zb, colormap=colormap, colorrange=zrange)#, colorrange=(-1, 1.0).*vis)
end
    BZdecorations!(pcustom, ax)
# Colorbar(fig[1,2], ax)  # Add a colorbar
    ϵ = 0.00001
    cb = Colorbar(fig[1, 2], hm)
 
    xlims!(ax, a[1], b[1])
    ylims!(ax, a[2], b[2])
    return fig
end
# Out:
# plotmap (generic function with 3 methods)

# %% [markdown]
# #### OMM contribution

# %%
# Berry
points= 100
temp = 5
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
integrand(q) = k_linear_magnetorresistance(:x,:x,:x, ParamsHF(pcustom, μ = mu), q, ofmts; T = temp, 
    Ω_contr = false)
Zo = funcmaps(ParamsHF(pcustom, μ = mu), integrand, points);

# %%
plotmap(pcustom, Zo, "OMM contribution,  T = $(temp)K", points, zrange = (-1,1).*1e-2)

# %%
magneto_conductivity(:x,:x,:x, ParamsHF(pcustom, μ = mu), ofmts; T = 5, 
    τ = 200, evals = 1000, Ω_contr = false)
# Out:
# 1.6337251678763797e-14

# %%
sum(Zo)
# Out:
# 1.2656542480726785e-13

# %% [markdown]
# #### BC contribution

# %%
# Berry
points= 100
temp = 5
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
integrand(q) = k_linear_magnetorresistance(:x,:x,:x, ParamsHF(pcustom, μ = mu), q, ofmts; T = temp, omm_contr = false)
Zb = funcmaps(ParamsHF(pcustom, μ = mu), integrand, points);

# %%
plotmap(pcustom, Zb, "Convoluted Berry curvature contribution,  T = $(temp)K", points, zrange = (-1,1).*1e-3)
# plotmap(pcustom, Zb, "Convoluted -vx^2 Ωx + vxvy Ωy [Å²],  T = $(temp)K", points)

# %%
magneto_conductivity(:x,:x,:x, ParamsHF(pcustom, μ = mu), ofmts; T = 5, 
    τ = 200, evals = 10000, Ω_contr = true, omm_contr = false, fermi_surface = false)
# Out:
# 1.5795147514794505e-5

# %%
sum(Zb)
# Out:
# -1.8471837393008173e-9

# %% [markdown]
# #### Berry curvature

# %%
# Berry
points= 50
temp = 1
l = 8
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
integrand(q) = k_inplaneberry(:x, ParamsHF(pcustom, μ = mu), q, ofmts, l; T = temp)
Zb = funcmaps(ParamsHF(pcustom, μ = mu), integrand, points);

# %%
plotmap(pcustom, Zb, "Unonvoluted Ωx [Å²], #flatband = $(l)", points)

# %%
# Berry Fermi surface
points= 50
temp = 10
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
integrand(q) = k_inplaneberry(:x, ParamsHF(pcustom, μ = mu), q, ofmts; T = temp)
Zb = funcmaps(ParamsHF(pcustom, μ = mu), integrand, points);

# %%
plotmap(pcustom, Zb, "Convoluted Ωx, T = $(temp)K", points)#, zrange = (-5,5) )

# %%
plotmap(pcustom, Zb, "Convoluted vx, T = $(temp)K", points)

# %% [markdown]
# #### Fermi surface

# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
temp = 5
points= 200
integrand(q) = k_fermisurface(:x, ParamsHF(pcustom, μ = mu), q, ofmts; T = temp)
Zf = funcmaps(ParamsHF(pcustom, μ = mu), integrand, points);

# %%
plotmap(pcustom, Zf, "Fermi surface: μ = $(mu) meV, ofmts = $(round.(diag(ofmts), digits = 1)), T = $(temp)K", points,
    colormap = cgrad([:white,:orange, :purple, :black]))

# %%
hist(Zb)

# %%
kv = K1
temp = 0.1
h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kv, ofmts);
ϵs, ψs = eigen(Matrix(h))
dfs = d_f(ϵs, 0, temp);
fig = Figure(); ax = Axis(fig[1,1], title = "number of states at the Fermi surface at k = $(round.(kv,digits=2)) and T = $(temp)K")
hist!(ax, dfs, bins = 1000)
ylims!(ax, 0, 12)
# xlims!(ax, -0.1, 0)
fig

# %% [markdown]
# ##### Form of Rz

# %%
pend = K2[2] / K2[1]
vals = real([non_local(p,-K2 + abs(K1[1]) .* [i, i*pend] ./ abs(2K1[1])   ) for i in -0.1:0.00001:0.2])
fig = Figure(); ax = Axis(fig[1,1]); lines!(ax, vals)
fig

# %% [markdown]
# ##### Rz

# %%
h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kv, ofmts)
ϵs, ψs = eigen(Matrix(h));

hist(ϵs, bins = 1000);

# %%
fig = Figure(); ax = Axis(fig[1,1], xlabel = "Rz_n [Å]", title = "Histogram of Rz at k = $(round.(kv, digits = 2))")
rzvals = real.(diagrz(pcustom, mu, ofmts, kv))
hist!(ax, rzvals, bins = 1000)
xlims!(ax, -3,3)
ylims!(ax, 0,12)

fig

# %%
function diagrz(pcustom, mu, ofmts, kvect, l)
    d = Dict(1 => 57, 2 => 58, 3 => 59, 4 => 60, 5 => 61, 6 => 62, 7 => 63, 8 => 64)
    diagrz(pcustom, mu, ofmts, kvect)[d[l]]
end
function diagrz(pcustom, mu, ofmts, kvect)
    h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kvect, ofmts)
    ϵs, ψs = eigen(Matrix(h))
    rzmat = rz(ψs, ParamsHF(pcustom, μ = mu), kvect, ofmts) #* a0;
    return diag(rzmat)
end
# Out:
# diagrz (generic function with 2 methods)

# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
l = 2
integrandrz(q) = diagrz(pcustom, mu, ofmts, q, l)
rzmap = funcmaps(pcustom, integrandrz);

# %%
plotmap(pcustom, real.(rzmap), "rz map projected on the flat band $(l)")

# %% [markdown]
# ##### velocities

# %%
function diagrx(pcustom, mu, ofmts, kvect)
    h = hf_valley_spin_hamiltonian(ParamsHF(pcustom, μ = mu), kvect, ofmts)
    ϵs, ψs = eigen(Matrix(h))
    dhx = dhf_hamiltonian(p, :x, ofmts)
    # rx = r(ϵs, ψs, dhx) 
    vx = vel(ψs, dh)
    diag(vx)
end
# Out:
# diagrx (generic function with 1 method)

# %%
fig = Figure(); ax = Axis(fig[1,1], xlabel = "vx_n [Å]", title = "Histogram of vx at k = $(round.(kv, digits = 2))")
rzvals = real(diagrx(pcustom, mu, ofmts, kv))
hist!(ax, rzvals, bins = 1000)
# xlims!(ax, -3,3)
# ylims!(ax, 0,12)
fig

# %% [markdown]
# #### INTEGRAND

# %%
# Define number of grid points
# RUN Self-consistent bands Heavy Fermion section
integrand(q) = k_linear_magnetorresistance(:x, :x, :x,
    ParamsHF(pcustom, μ = mu), q, ofmts; T = 1, τ = 200, Ω_contr = true, omm_contr = true, fermi_surface = false)
M, xmin, xmax = int_boundaries(p)
a = [-xmax[1], xmin[2]]
b = [xmax[1], xmax[2]]

n = 40  # resolution (100x100 grid)
# Generate grid points
x = range(a[1], b[1], length=n)
y = range(a[2], b[2], length=n)

# Evaluate f on the grid
Z = [integrand([xi, yi]) for xi in x, yi in y];  # notice: [row, column] ordering

# %%
# Create the density plot

vis = 1e9
fig = Figure(size=(1.23*600,600))
ax = Axis(fig[1, 1], xlabel="kx", ylabel="ky", title="Magnetoconductivity integrand")
# heatmap!(ax, x, y, Z, colormap=:redsblues)#, colorrange=(-1, 1.0).*vis)
cmap = cgrad([:red, :white, :blue])
hm = heatmap!(ax, x, y, real(Z), colormap=cmap, colorrange=(-1, 1.0).*vis)
BZdecorations!(pcustom, ax)
# Colorbar(fig[1,2], ax)  # Add a colorbar
cb = Colorbar(fig[1, 2], hm)
xlims!(ax, a[1]-ϵ, b[1]+ϵ)
ylims!(ax, a[2]-ϵ, b[2]+ϵ)
fig

# %%
magneto_conductivity(:x, :x, :x, ParamsHF(pcustom, μ = mu), 
ofmts, T = 1, τ = 200, evals = 10000, Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# 0.00015419230608512707

# %%
t1 = tauz(simportedqah)
t2 = tauz(simportedvp)
fig = Figure()
ax = Axis(fig[1,1]) 
lines!(ax, simportedvp.ns, t1, label = "qah")
lines!(ax, simportedvp.ns, t2, label = "vp")
axislegend(ax, position = :lt)
fig

# %% [markdown]
# ### Selfconsistent

# %%
# Define number of grid points
# RUN Self-consistent bands Heavy Fermion section

integrand(q) = k_linear_magnetorresistance(:x, :x, :x, 
    ParamsHF(p, μ = sd.mus[itn]), q, diagm(sd.ofmats[itn]); T = 1, τ = 200,
    Ω_contr = true, omm_contr = false, fermi_surface = false)
M, xmin, xmax = int_boundaries(p)
a = [-xmax[1], xmin[2]];
b = [xmax[1], xmax[2]];

n = 40  # resolution (100x100 grid)
# Generate grid points
x = range(a[1], b[1], length=n)
y = range(a[2], b[2], length=n)


# Evaluate f on the grid
Z = [integrand([xi, yi]) for xi in x, yi in y];  # notice: [row, column] ordering

# %%
# Create the density plot

vis = 1e15
fig = Figure(size=(1.23*600,600))
ax = Axis(fig[1, 1], xlabel="kx", ylabel="ky", title="Magnetoconductivity integrand")
# heatmap!(ax, x, y, Z, colormap=:redsblues)#, colorrange=(-1, 1.0).*vis)
cmap = cgrad([:red, :white, :blue])
hm = heatmap!(ax, x, y, real(Z), colormap=cmap, colorrange=(-1, 1.0).*vis)
BZdecorations!(p, ax)
# Colorbar(fig[1,2], ax)  # Add a colorbar
cb = Colorbar(fig[1, 2], hm)
xlims!(ax, a[1]-ϵ, b[1]+ϵ)
ylims!(ax, a[2]-ϵ, b[2]+ϵ)
fig

# %% [markdown]
# #### Electron density

# %%
electron_density(p, sd; evals = 10000) / 10^4 # in #electrons/cm^{2}
# Out:
# 8.942366859151096e12

# %% [markdown]
# #### Fermi Surface

# %%
# Define number of grid points
integrand(q) = k_linear_magnetorresistance(:x, :x, :x, 
    ParamsHF(p, μ = sd.mus[1]), q, diagm(sd.ofmats[1]); T = 1, τ = 200,
    Ω_contr = true, omm_contr = true, fermi_surface = true)
M, xmin, xmax = int_boundaries(p)
# a = [0, xmin[2]];
# b = [xmax[1]/2, xmax[2]];
a = [-xmax[1], xmin[2]];
b = [xmax[1], xmax[2]];
n = 50  # resolution (100x100 grid)

# Generate grid points
x = range(a[1], b[1], length=n)
y = range(a[2], b[2], length=n)

# Evaluate f on the grid
Z = [integrand([xi, yi]) for xi in x, yi in y];  # notice: [row, column] ordering

# %%
# Create the density plot
vis = 1e21
ϵ = norm(K1)/100
fig = Figure(size=(1.154*600,600))
ax = Axis(fig[1, 1], xlabel="kx", ylabel="ky", title="Fermi surface")
# heatmap!(ax, x, y, Z, colormap=:redsblues)#, colorrange=(-1, 1.0).*vis)
hm = heatmap!(ax, x, y, Z, colormap=:grays, colorrange=(-1, 0).*vis)
BZdecorations!(p, ax)
xlims!(ax, a[1]-ϵ, b[1]+ϵ)
ylims!(ax, a[2]-ϵ, b[2]+ϵ)
cb = Colorbar(fig[1, 2], hm)

# Colorbar(fig[1,2], ax)  # Add a colorbar
fig

# %% [markdown]
# #### Integral

# %%
# of = diagm([1,1,1,1,0,0,0,0]) .*2
# # of0 = diagm(ones(8) .* 0.5)
# hf_plotbands(ParamsHF(p, μ = 0), of, kpoints = 101, res = (1.5*600,1.5*400))

# %%
#of = diagm(rand(8))
magneto_conductivity(:x, :x, :x, ParamsHF(p, μ = 0), of, T = 10, τ = 200, evals = 10,
    Ω_contr = true, omm_contr = true)
# Out:
# UndefVarError: `of` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/MR.ipynb:3

# %%
A =  0.0025297643588104214 # area of the BZ

# %% [markdown]
# #### Density of states at the Fermi level

# %%
τp = 200
N0 = -magneto_conductivity(:x, :x, :x, p, sd, T = 1, τ = τp, evals = 5000,
    fermi_surface = true)*(ang_to_m^2)/(τp*femto_to_seconds) #units #kpoints/Å^2 meV
# Out:
# 6.559837527117984e-5

# %% [markdown]
# Self consistent dos with the filling

# %%
function DOS_selfconsistent(p, fillings; config = SelfConsistency_config_random(1e-6, 4, 1, 1, 30))
    DOS = []
    for ν in fillings
        sof, sμ, se = guided_sweep(:β, p, config, [ν])
        sd = Self_consistent_data(sof, sμ, se, ν) 
        N0 = -magneto_conductivity(:x, :x, :x, p, sd, T = 10, τ = τp, evals = 500,
        fermi_surface = true)*(ang_to_m^2)/(τp*femto_to_seconds)
        append!(DOS, N0)
    end
    return DOS
end
# Out:
# DOS_selfconsistent (generic function with 2 methods)

# %%
fillings = 0:0.05:3.999
mydos = DOS_selfconsistent(p, config, fillings)
# Out:
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0589, 0.9096, 0.061, 0.9146, 0.0537, 0.9225, 0.06, 0.9261]
#  2.. It: 2 with Of: [0.0616, 0.9378, 0.0643, 0.9403, 0.0616, 0.938, 0.0643, 0.9404]
#  3.. It: 3 with Of: [0.0605, 0.9368, 0.063, 0.9394, 0.0605, 0.9368, 0.063, 0.9394]
#  4.. It: 4 with Of: [0.0606, 0.9369, 0.0631, 0.9395, 0.0606, 0.9369, 0.0631, 0.9395]
# energy: -13162.782622249208
#  TIME: 2706 milliseconds
# Energy without penalities:-13162.782622249208
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.014, 0.9321, 0.0588, 0.9212, 0.0586, 0.9311, 0.0688, 0.93]
#  2.. It: 2 with Of: [0.061, 0.9379, 0.0641, 0.9402, 0.1761, 0.9418, 0.0643, 0.9403]
#  3.. It: 3 with Of: [0.0591, 0.9353, 0.0615, 0.938, 0.1749, 0.9399, 0.0615, 0.938]
#  4.. It: 4 with Of: [0.0593, 0.9355, 0.0617, 0.9382, 0.1751, 0.9401, 0.0617, 0.9382]
# energy: -13161.951948252447
#  TIME: 2763 milliseconds
# Energy without penalities:-13161.951948252447
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0564, 0.9265, 0.0572, 0.9278, 0.1752, 0.9351, 0.0631, 0.9296]
#  2.. It: 2 with Of: [0.0597, 0.9359, 0.0621, 0.9385, 0.1756, 0.9404, 0.0621, 0.9385]
#  3.. It: 3 with Of: [0.0593, 0.9354, 0.0616, 0.9381, 0.1751, 0.94, 0.0616, 0.9381]
#  4.. It: 4 with Of: [0.0593, 0.9355, 0.0616, 0.9382, 0.1751, 0.9401, 0.0616, 0.9382]
# energy: -13161.951948217593
#  TIME: 2754 milliseconds
# Energy without penalities:-13161.951948217593
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0568, 0.9158, 0.154, 0.9322, 0.0534, 0.9262, 0.0542, 0.926]
#  2.. It: 2 with Of: [0.1747, 0.9407, 0.0639, 0.9392, 0.1747, 0.9408, 0.0627, 0.9391]
#  3.. It: 3 with Of: [0.1789, 0.9398, 0.061, 0.9367, 0.1789, 0.9398, 0.0609, 0.9367]
#  4.. It: 4 with Of: [0.179, 0.9398, 0.061, 0.9367, 0.179, 0.9398, 0.061, 0.9367]
# energy: -13159.498815757554
#  TIME: 2766 milliseconds
# Energy without penalities:-13159.498815757554
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0798, 0.9434, 0.4547, 0.9468, 0.0792, 0.9445, 0.0855, 0.9477]
#  2.. It: 2 with Of: [0.0607, 0.9311, 0.1562, 0.9355, 0.0607, 0.9312, 0.0583, 0.9336]
#  3.. It: 3 with Of: [0.1741, 0.9404, 0.0633, 0.9387, 0.1741, 0.9404, 0.0621, 0.9386]
#  4.. It: 4 with Of: [0.179, 0.9398, 0.061, 0.9367, 0.179, 0.9398, 0.061, 0.9367]
# energy: -13159.498815734622
#  TIME: 2814 milliseconds
# Energy without penalities:-13159.498815734622
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0854, 0.9468, 0.097, 0.9424, 0.0831, 0.9454, 0.4639, 0.945]
#  2.. It: 2 with Of: [0.0604, 0.9308, 0.0617, 0.9333, 0.0604, 0.9308, 0.156, 0.9351]
#  3.. It: 3 with Of: [0.1787, 0.9411, 0.0622, 0.9386, 0.1787, 0.9411, 0.1531, 0.9396]
#  4.. It: 4 with Of: [0.1776, 0.9389, 0.0635, 0.9356, 0.1776, 0.9389, 0.0646, 0.9357]
# energy: -13161.810451630128
#  TIME: 2783 milliseconds
# Energy without penalities:-13161.810451630128
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0646, 0.9306, 0.0686, 0.936, 0.0611, 0.9346, 0.4384, 0.9398]
#  2.. It: 2 with Of: [0.0617, 0.9325, 0.0593, 0.9349, 0.0617, 0.9326, 0.1576, 0.9367]
#  3.. It: 3 with Of: [0.1786, 0.941, 0.062, 0.9385, 0.1786, 0.941, 0.153, 0.9396]
#  4.. It: 4 with Of: [0.1776, 0.9389, 0.0635, 0.9356, 0.1776, 0.9389, 0.0646, 0.9357]
# energy: -13159.395753952227
#  TIME: 2790 milliseconds
# Energy without penalities:-13159.395753952227
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0772, 0.9468, 0.0789, 0.9413, 0.2538, 0.9412, 0.0846, 0.9427]
#  2.. It: 2 with Of: [0.1771, 0.9396, 0.0646, 0.9365, 0.1661, 0.9383, 0.0646, 0.9365]
#  3.. It: 3 with Of: [0.0118, 0.9374, 0.0649, 0.937, 0.179, 0.9399, 0.0649, 0.937]
#  4.. It: 4 with Of: [0.1779, 0.9411, 0.0622, 0.9386, 0.1667, 0.9401, 0.0622, 0.9386]
# energy: -13160.790905291371
#  TIME: 2844 milliseconds
# Energy without penalities:-13160.790905291371
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0573, 0.9293, 0.063, 0.9262, 0.3025, 0.9375, 0.1567, 0.9388]
#  2.. It: 2 with Of: [0.0623, 0.9334, 0.0638, 0.9357, 0.1661, 0.9378, 0.0649, 0.936]
#  3.. It: 3 with Of: [0.1792, 0.941, 0.0627, 0.9383, 0.1671, 0.9399, 0.0627, 0.9383]
#  4.. It: 4 with Of: [0.0118, 0.9374, 0.0648, 0.9369, 0.0116, 0.9374, 0.0648, 0.9369]
# energy: -13137.301959606297
#  TIME: 2806 milliseconds
# Energy without penalities:-13137.301959606297
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0746, 0.9367, 0.4784, 0.9407, 0.075, 0.9383, 0.0788, 0.9435]
#  2.. It: 2 with Of: [0.0608, 0.9313, 0.1568, 0.9356, 0.0608, 0.9313, 0.062, 0.9339]
#  3.. It: 3 with Of: [0.1796, 0.9412, 0.154, 0.9397, 0.1796, 0.9412, 0.063, 0.9386]
#  4.. It: 4 with Of: [0.0104, 0.9361, 0.0646, 0.9356, 0.0104, 0.9361, 0.0634, 0.9356]
# energy: -13137.476941941293
#  TIME: 2718 milliseconds
# Energy without penalities:-13137.476941941293
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0664, 0.9377, 0.6844, 0.9433, 0.067, 0.9383, 0.078, 0.9402]
#  2.. It: 2 with Of: [0.0587, 0.9284, 0.588, 0.9345, 0.0587, 0.9284, 0.0563, 0.9311]
#  3.. It: 3 with Of: [0.0563, 0.9302, 0.4356, 0.936, 0.0563, 0.9302, 0.0579, 0.9334]
#  4.. It: 4 with Of: [0.062, 0.9331, 0.4356, 0.9376, 0.062, 0.9331, 0.0597, 0.9354]
# energy: -13160.46666632588
#  TIME: 2734 milliseconds
# Energy without penalities:-13160.46666632588
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.4423, 0.9419, 0.089, 0.9473, 0.078, 0.9497, 0.0858, 0.9423]
#  2.. It: 2 with Of: [0.3017, 0.9368, 0.062, 0.9338, 0.0607, 0.9313, 0.062, 0.9338]
#  3.. It: 3 with Of: [0.3033, 0.9393, 0.0649, 0.9369, 0.1775, 0.9398, 0.0649, 0.9369]
#  4.. It: 4 with Of: [0.3013, 0.9379, 0.0631, 0.9352, 0.1772, 0.9386, 0.0631, 0.9352]
# energy: -13159.656412563092
#  TIME: 2739 milliseconds
# Energy without penalities:-13159.656412563092
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0696, 0.9432, 0.4459, 0.942, 0.0698, 0.9424, 0.4456, 0.9467]
#  2.. It: 2 with Of: [0.0572, 0.9261, 0.1516, 0.9313, 0.0572, 0.9261, 0.1516, 0.9313]
#  3.. It: 3 with Of: [0.1787, 0.9406, 0.1571, 0.9391, 0.1787, 0.9406, 0.1571, 0.9391]
#  4.. It: 4 with Of: [0.0092, 0.935, 0.0634, 0.9344, 0.0092, 0.935, 0.0634, 0.9344]
# energy: -13137.632683429221
#  TIME: 2718 milliseconds
# Energy without penalities:-13137.632683429221
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0651, 0.9394, 0.0685, 0.9309, 0.543, 0.9414, 0.0681, 0.9376]
#  2.. It: 2 with Of: [0.0604, 0.9309, 0.0615, 0.9334, 0.3925, 0.9368, 0.0615, 0.9335]
#  3.. It: 3 with Of: [0.0624, 0.9334, 0.0638, 0.9358, 0.3928, 0.9386, 0.0638, 0.9358]
#  4.. It: 4 with Of: [0.0622, 0.9333, 0.0636, 0.9357, 0.3926, 0.9384, 0.0636, 0.9357]
# energy: -13158.531919686577
#  TIME: 2744 milliseconds
# Energy without penalities:-13158.531919686577
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0068, 0.9252, 0.265, 0.9305, 0.0562, 0.9137, 0.06, 0.923]
#  2.. It: 2 with Of: [0.1787, 0.9411, 0.5904, 0.9403, 0.1794, 0.941, 0.0629, 0.9384]
#  3.. It: 3 with Of: [0.0586, 0.9266, 0.5315, 0.9338, 0.0586, 0.9266, 0.0583, 0.9295]
#  4.. It: 4 with Of: [0.0611, 0.9317, 0.4417, 0.9367, 0.0611, 0.9317, 0.0586, 0.9342]
# energy: -13158.470329070431
#  TIME: 2707 milliseconds
# Energy without penalities:-13158.470329070431
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.057, 0.9298, 0.058, 0.9215, 0.37, 0.9287, 0.0624, 0.9323]
#  2.. It: 2 with Of: [0.0629, 0.9341, 0.0644, 0.9363, 0.4419, 0.939, 0.0644, 0.9365]
#  3.. It: 3 with Of: [0.0616, 0.9325, 0.0629, 0.935, 0.4413, 0.9379, 0.0629, 0.935]
#  4.. It: 4 with Of: [0.0617, 0.9326, 0.063, 0.9351, 0.4415, 0.938, 0.063, 0.9351]
# energy: -13158.172787836738
#  TIME: 2718 milliseconds
# Energy without penalities:-13158.172787836738
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0778, 0.9428, 0.0882, 0.9492, 0.0809, 0.9428, 0.979, 0.9482]
#  2.. It: 2 with Of: [0.0554, 0.9227, 0.056, 0.9261, 0.0555, 0.9227, 0.7375, 0.9313]
#  3.. It: 3 with Of: [0.0551, 0.9282, 0.0566, 0.9316, 0.0551, 0.9282, 0.6263, 0.9347]
#  4.. It: 4 with Of: [0.06, 0.9304, 0.0576, 0.9329, 0.06, 0.9304, 0.6261, 0.9357]
# energy: -13157.569082023552
#  TIME: 2718 milliseconds
# Energy without penalities:-13157.569082023552
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.074, 0.9391, 0.0813, 0.9492, 0.9162, 0.9487, 0.0835, 0.9419]
#  2.. It: 2 with Of: [0.0561, 0.9239, 0.0567, 0.9272, 0.7371, 0.9323, 0.0567, 0.9271]
#  3.. It: 3 with Of: [0.055, 0.9281, 0.0565, 0.9315, 0.7388, 0.9354, 0.0565, 0.9315]
#  4.. It: 4 with Of: [0.0548, 0.9279, 0.0563, 0.9313, 0.7386, 0.9353, 0.0563, 0.9313]
# energy: -13156.399514904868
#  TIME: 2749 milliseconds
# Energy without penalities:-13156.399514904868
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.2935, 0.9155, 0.0575, 0.9068, 0.1689, 0.9207, 0.2614, 0.9222]
#  2.. It: 2 with Of: [0.3, 0.9368, 0.062, 0.9337, 0.0089, 0.9345, 0.1541, 0.9355]
#  3.. It: 3 with Of: [0.3921, 0.939, 0.0644, 0.9364, 0.1761, 0.9395, 0.1552, 0.9377]
#  4.. It: 4 with Of: [0.3897, 0.9364, 0.0609, 0.9328, 0.1747, 0.9369, 0.062, 0.9329]
# energy: -13153.434634257788
#  TIME: 2744 milliseconds
# Energy without penalities:-13153.434634257788
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0667, 0.936, 0.1652, 0.9384, 0.8212, 0.9376, 0.0685, 0.9394]
#  2.. It: 2 with Of: [0.0566, 0.9249, 0.0582, 0.9281, 0.7365, 0.9329, 0.0572, 0.928]
#  3.. It: 3 with Of: [0.0549, 0.928, 0.0564, 0.9314, 0.7387, 0.9354, 0.0564, 0.9314]
#  4.. It: 4 with Of: [0.0548, 0.9279, 0.0563, 0.9313, 0.7386, 0.9353, 0.0563, 0.9313]
# energy: -13156.399514886096
#  TIME: 2718 milliseconds
# Energy without penalities:-13156.399514886096
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3099, 0.9435, 0.0692, 0.9339, 0.0647, 0.941, 0.9679, 0.9364]
#  2.. It: 2 with Of: [0.0562, 0.9198, 0.0543, 0.9233, 0.054, 0.9199, 0.7352, 0.9295]
#  3.. It: 3 with Of: [0.0552, 0.9284, 0.0567, 0.9318, 0.0552, 0.9284, 0.792, 0.9349]
#  4.. It: 4 with Of: [0.0544, 0.9271, 0.0558, 0.9306, 0.0544, 0.9271, 0.9048, 0.9346]
# energy: -13155.179699571316
#  TIME: 2716 milliseconds
# Energy without penalities:-13155.179699571316
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3032, 0.9314, 0.6574, 0.928, 0.0592, 0.9315, 0.0578, 0.9329]
#  2.. It: 2 with Of: [0.0596, 0.926, 0.7358, 0.9334, 0.0572, 0.926, 0.0579, 0.929]
#  3.. It: 3 with Of: [0.055, 0.928, 0.9047, 0.9352, 0.0549, 0.928, 0.0564, 0.9314]
#  4.. It: 4 with Of: [0.0534, 0.9253, 0.9048, 0.9335, 0.0534, 0.9253, 0.0546, 0.929]
# energy: -13155.179515532871
#  TIME: 2774 milliseconds
# Energy without penalities:-13155.179515532871
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.389, 0.9208, 0.0597, 0.9101, 0.1619, 0.9238, 0.1511, 0.9197]
#  2.. It: 2 with Of: [0.7363, 0.9373, 0.0621, 0.9339, 0.1759, 0.9377, 0.0632, 0.9341]
#  3.. It: 3 with Of: [0.902, 0.9339, 0.0582, 0.9293, 0.0585, 0.9264, 0.0582, 0.9293]
#  4.. It: 4 with Of: [0.9042, 0.9336, 0.058, 0.929, 0.0572, 0.926, 0.058, 0.929]
# energy: -13154.778605403671
#  TIME: 2814 milliseconds
# Energy without penalities:-13154.778605403671
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0117, 0.9242, 0.1564, 0.9335, 0.0112, 0.9296, 0.792, 0.9283]
#  2.. It: 2 with Of: [0.0578, 0.9277, 0.0602, 0.9308, 0.0578, 0.9278, 0.9047, 0.9345]
#  3.. It: 3 with Of: [0.0572, 0.9259, 0.0579, 0.929, 0.0572, 0.9259, 0.9047, 0.9334]
#  4.. It: 4 with Of: [0.0573, 0.926, 0.058, 0.9291, 0.0573, 0.926, 0.9049, 0.9335]
# energy: -13154.74225767778
#  TIME: 2749 milliseconds
# Energy without penalities:-13154.74225767778
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0755, 0.9419, 0.8208, 0.9422, 0.0818, 0.9421, 0.476, 0.946]
#  2.. It: 2 with Of: [0.0536, 0.9189, 0.8976, 0.9291, 0.0536, 0.9189, 0.0577, 0.9225]
#  3.. It: 3 with Of: [0.0576, 0.9266, 0.9053, 0.9338, 0.0576, 0.9266, 0.0584, 0.9296]
#  4.. It: 4 with Of: [0.0572, 0.926, 0.9048, 0.9334, 0.0572, 0.926, 0.058, 0.9291]
# energy: -13154.742257937774
#  TIME: 2791 milliseconds
# Energy without penalities:-13154.742257937774
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3, 0.9374, 0.9037, 0.9377, 0.0597, 0.93, 0.0632, 0.9369]
#  2.. It: 2 with Of: [0.1692, 0.9314, 0.901, 0.9307, 0.0547, 0.9214, 0.0552, 0.9249]
#  3.. It: 3 with Of: [0.1698, 0.9333, 0.9035, 0.9324, 0.0563, 0.9244, 0.0569, 0.9276]
#  4.. It: 4 with Of: [0.1696, 0.9331, 0.9033, 0.9323, 0.0562, 0.9242, 0.0568, 0.9274]
# energy: -13153.338056418514
#  TIME: 2776 milliseconds
# Energy without penalities:-13153.338056418514
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0637, 0.9285, 0.0615, 0.9197, 0.9071, 0.9324, 0.1581, 0.9319]
#  2.. It: 2 with Of: [0.1681, 0.9331, 0.0568, 0.9273, 0.9028, 0.9325, 0.0578, 0.9275]
#  3.. It: 3 with Of: [0.1695, 0.9331, 0.0568, 0.9273, 0.9027, 0.9324, 0.0568, 0.9273]
#  4.. It: 4 with Of: [0.1696, 0.9331, 0.0568, 0.9273, 0.9027, 0.9324, 0.0568, 0.9273]
# energy: -13153.372162183485
#  TIME: 2734 milliseconds
# Energy without penalities:-13153.372162183485
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0723, 0.9423, 0.0793, 0.9425, 0.3657, 0.9397, 0.9202, 0.94]
#  2.. It: 2 with Of: [0.0537, 0.9193, 0.0541, 0.9228, 0.0025, 0.9243, 0.8994, 0.9293]
#  3.. It: 3 with Of: [0.1707, 0.9351, 0.0589, 0.9303, 0.17, 0.9351, 0.906, 0.9343]
#  4.. It: 4 with Of: [0.1677, 0.9317, 0.0554, 0.9253, 0.1677, 0.9317, 0.9015, 0.9309]
# energy: -13151.852267838283
#  TIME: 2742 milliseconds
# Energy without penalities:-13151.852267838283
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0612, 0.9225, 0.9078, 0.939, 0.1772, 0.9405, 0.4356, 0.9398]
#  2.. It: 2 with Of: [0.0527, 0.9167, 0.8975, 0.9279, 0.164, 0.9287, 0.2585, 0.9273]
#  3.. It: 3 with Of: [0.1657, 0.9312, 0.9009, 0.9305, 0.1672, 0.9313, 0.1461, 0.9272]
#  4.. It: 4 with Of: [0.1669, 0.931, 0.9006, 0.9302, 0.1669, 0.931, 0.0557, 0.9243]
# energy: -13156.037957593007
#  TIME: 2744 milliseconds
# Energy without penalities:-13156.037957593007
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.908, 0.9314, 0.1584, 0.933, 0.0609, 0.9275, 0.4372, 0.9346]
#  2.. It: 2 with Of: [0.8974, 0.9284, 0.054, 0.9212, 0.0529, 0.9174, 0.2589, 0.9276]
#  3.. It: 3 with Of: [0.9019, 0.9319, 0.0562, 0.9264, 0.1672, 0.9324, 0.2607, 0.9313]
#  4.. It: 4 with Of: [0.8999, 0.9303, 0.0547, 0.9241, 0.1668, 0.931, 0.1457, 0.9268]
# energy: -13150.731665094565
#  TIME: 2757 milliseconds
# Energy without penalities:-13150.731665094565
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.2987, 0.9331, 0.0587, 0.9125, 0.0591, 0.9259, 0.905, 0.9315]
#  2.. It: 2 with Of: [0.2921, 0.9308, 0.0556, 0.9253, 0.1664, 0.9318, 0.9017, 0.931]
#  3.. It: 3 with Of: [0.1552, 0.9282, 0.0545, 0.9237, 0.1664, 0.9307, 0.9001, 0.9299]
#  4.. It: 4 with Of: [0.0024, 0.9274, 0.0559, 0.926, 0.0025, 0.9275, 0.9021, 0.9314]
# energy: -13139.115609572304
#  TIME: 2738 milliseconds
# Energy without penalities:-13139.115609572304
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.5457, 0.9447, 0.9162, 0.936, 0.0676, 0.9344, 0.0737, 0.9365]
#  2.. It: 2 with Of: [0.3807, 0.928, 0.8972, 0.9276, 0.0525, 0.9164, 0.0526, 0.9201]
#  3.. It: 3 with Of: [0.3822, 0.9309, 0.9009, 0.9305, 0.1656, 0.9312, 0.055, 0.9246]
#  4.. It: 4 with Of: [0.2906, 0.9284, 0.8989, 0.929, 0.1652, 0.9297, 0.0537, 0.9222]
# energy: -13151.308631370053
#  TIME: 2746 milliseconds
# Energy without penalities:-13151.308631370053
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3766, 0.9311, 0.1632, 0.9341, 0.064, 0.932, 0.964, 0.9358]
#  2.. It: 2 with Of: [0.379, 0.9285, 0.0539, 0.921, 0.1627, 0.9289, 0.8987, 0.9281]
#  3.. It: 3 with Of: [0.3804, 0.9296, 0.0538, 0.9225, 0.1655, 0.9299, 0.8991, 0.9291]
#  4.. It: 4 with Of: [0.3803, 0.9295, 0.0538, 0.9224, 0.1654, 0.9298, 0.899, 0.9291]
# energy: -13149.097203258787
#  TIME: 2761 milliseconds
# Energy without penalities:-13149.097203258787
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9001, 0.9267, 0.5286, 0.9277, 0.0586, 0.9097, 0.0614, 0.9057]
#  2.. It: 2 with Of: [0.8983, 0.9291, 0.5245, 0.9289, 0.0535, 0.9184, 0.0537, 0.9219]
#  3.. It: 3 with Of: [0.8981, 0.929, 0.5243, 0.9288, 0.0534, 0.9184, 0.0536, 0.922]
#  4.. It: 4 with Of: [0.8981, 0.9291, 0.5243, 0.9288, 0.0534, 0.9184, 0.0536, 0.9221]
# energy: -13149.019888670457
#  TIME: 2812 milliseconds
# Energy without penalities:-13149.019888670457
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0583, 0.9172, 0.9057, 0.9324, 0.3904, 0.9338, 0.0626, 0.9298]
#  2.. It: 2 with Of: [0.165, 0.9306, 0.9002, 0.9299, 0.3815, 0.9304, 0.0546, 0.9238]
#  3.. It: 3 with Of: [0.1653, 0.9298, 0.8989, 0.929, 0.3802, 0.9294, 0.0537, 0.9223]
#  4.. It: 4 with Of: [0.1654, 0.9298, 0.899, 0.9291, 0.3803, 0.9295, 0.0538, 0.9224]
# energy: -13149.097203255069
#  TIME: 2778 milliseconds
# Energy without penalities:-13149.097203255069
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3693, 0.9339, 0.1551, 0.9392, 0.9106, 0.9326, 0.0624, 0.9376]
#  2.. It: 2 with Of: [0.3797, 0.9292, 0.0544, 0.9221, 0.8981, 0.9289, 0.0536, 0.9221]
#  3.. It: 3 with Of: [0.382, 0.9308, 0.0549, 0.9244, 0.9001, 0.9305, 0.0549, 0.9244]
#  4.. It: 4 with Of: [0.3818, 0.9307, 0.0548, 0.9242, 0.8999, 0.9304, 0.0548, 0.9242]
# energy: -13150.756581032882
#  TIME: 2776 milliseconds
# Energy without penalities:-13150.756581032882
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3862, 0.9186, 0.8983, 0.9207, 0.1699, 0.9285, 0.0574, 0.9126]
#  2.. It: 2 with Of: [0.3806, 0.9296, 0.8992, 0.9292, 0.1657, 0.93, 0.054, 0.9225]
#  3.. It: 3 with Of: [0.3803, 0.9295, 0.899, 0.9291, 0.1654, 0.9298, 0.0538, 0.9224]
#  4.. It: 4 with Of: [0.3803, 0.9295, 0.899, 0.9291, 0.1654, 0.9298, 0.0538, 0.9224]
# energy: -13149.097203247908
#  TIME: 2717 milliseconds
# Energy without penalities:-13149.097203247908
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9056, 0.9276, 0.0594, 0.9259, 0.1728, 0.9334, 0.6667, 0.9304]
#  2.. It: 2 with Of: [0.8941, 0.9259, 0.0511, 0.917, 0.0522, 0.9131, 0.658, 0.9258]
#  3.. It: 3 with Of: [0.8965, 0.9279, 0.0526, 0.9201, 0.0525, 0.9163, 0.6796, 0.9278]
#  4.. It: 4 with Of: [0.896, 0.9275, 0.0523, 0.9195, 0.0522, 0.9157, 0.6794, 0.9274]
# energy: -13146.54196012744
#  TIME: 2748 milliseconds
# Energy without penalities:-13146.54196012744
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.1745, 0.9236, 0.9041, 0.9298, 0.438, 0.9317, 0.0607, 0.9177]
#  2.. It: 2 with Of: [0.1646, 0.929, 0.8981, 0.9283, 0.3802, 0.9287, 0.0532, 0.9211]
#  3.. It: 3 with Of: [0.0002, 0.9243, 0.8991, 0.9291, 0.3804, 0.9296, 0.0538, 0.9225]
#  4.. It: 4 with Of: [0.1654, 0.9317, 0.9014, 0.9309, 0.7085, 0.9314, 0.0554, 0.9252]
# energy: -13157.845791690364
#  TIME: 2750 milliseconds
# Energy without penalities:-13157.845791690364
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0664, 0.936, 0.9154, 0.9434, 0.9075, 0.9448, 0.071, 0.9369]
#  2.. It: 2 with Of: [0.0499, 0.9094, 0.7266, 0.9235, 0.7259, 0.9238, 0.0497, 0.9135]
#  3.. It: 3 with Of: [0.0534, 0.9184, 0.7309, 0.929, 0.7303, 0.9292, 0.0536, 0.922]
#  4.. It: 4 with Of: [0.0531, 0.9177, 0.7303, 0.9285, 0.7297, 0.9288, 0.0532, 0.9214]
# energy: -13144.713340215245
#  TIME: 2720 milliseconds
# Energy without penalities:-13144.713340215245
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9132, 0.9378, 0.6535, 0.9396, 0.1794, 0.938, 0.1536, 0.9321]
#  2.. It: 2 with Of: [0.8923, 0.9246, 0.7237, 0.9245, 0.0514, 0.9107, 0.051, 0.9147]
#  3.. It: 3 with Of: [0.8957, 0.9272, 0.7284, 0.9271, 0.0521, 0.9152, 0.0521, 0.9191]
#  4.. It: 4 with Of: [0.8954, 0.927, 0.7282, 0.9269, 0.0519, 0.9149, 0.0519, 0.9187]
# energy: -13146.542482174267
#  TIME: 2700 milliseconds
# Energy without penalities:-13146.542482174267
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9014, 0.9319, 0.4327, 0.9301, 0.0594, 0.9244, 0.79, 0.9356]
#  2.. It: 2 with Of: [0.8884, 0.9216, 0.0515, 0.9091, 0.0488, 0.9054, 0.722, 0.9214]
#  3.. It: 3 with Of: [0.896, 0.9275, 0.0523, 0.9194, 0.0523, 0.9156, 0.7288, 0.9274]
#  4.. It: 4 with Of: [0.8954, 0.927, 0.0519, 0.9187, 0.0519, 0.9148, 0.7281, 0.9269]
# energy: -13144.566858779895
#  TIME: 2740 milliseconds
# Energy without penalities:-13144.566858779895
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.4745, 0.9503, 0.112, 0.9478, 0.7416, 0.949, 0.8476, 0.9447]
#  2.. It: 2 with Of: [0.1597, 0.9208, 0.0484, 0.9088, 0.7197, 0.9213, 0.8872, 0.9208]
#  3.. It: 3 with Of: [0.0523, 0.9135, 0.0513, 0.9173, 0.8917, 0.9264, 0.8949, 0.926]
#  4.. It: 4 with Of: [0.0508, 0.9119, 0.0507, 0.9159, 0.8931, 0.9253, 0.8938, 0.925]
# energy: -13144.573349923685
#  TIME: 2727 milliseconds
# Energy without penalities:-13144.573349923685
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9062, 0.9287, 0.9058, 0.9373, 0.0589, 0.9244, 0.1563, 0.9348]
#  2.. It: 2 with Of: [0.8907, 0.9233, 0.8913, 0.9231, 0.0497, 0.9085, 0.0502, 0.9127]
#  3.. It: 3 with Of: [0.8934, 0.9255, 0.894, 0.9253, 0.051, 0.9122, 0.0508, 0.9162]
#  4.. It: 4 with Of: [0.8932, 0.9253, 0.8938, 0.9251, 0.0508, 0.9119, 0.0507, 0.9159]
# energy: -13144.573349042243
#  TIME: 2725 milliseconds
# Energy without penalities:-13144.573349042243
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.1635, 0.9244, 0.6584, 0.9218, 0.8941, 0.9163, 0.2451, 0.9219]
#  2.. It: 2 with Of: [0.1596, 0.9247, 0.8891, 0.9244, 0.8921, 0.9244, 0.0518, 0.9144]
#  3.. It: 3 with Of: [0.159, 0.9243, 0.8921, 0.9238, 0.8915, 0.9241, 0.0499, 0.9138]
#  4.. It: 4 with Of: [0.1591, 0.9244, 0.8922, 0.9238, 0.8916, 0.9241, 0.0499, 0.9138]
# energy: -13142.597144008523
#  TIME: 2742 milliseconds
# Energy without penalities:-13142.597144008523
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3099, 0.9421, 0.8059, 0.9418, 0.1729, 0.9426, 0.9154, 0.9466]
#  2.. It: 2 with Of: [0.1573, 0.9208, 0.8864, 0.9207, 0.1553, 0.9209, 0.8882, 0.9207]
#  3.. It: 3 with Of: [0.1578, 0.9232, 0.8908, 0.9228, 0.1578, 0.9232, 0.8908, 0.9228]
#  4.. It: 4 with Of: [0.1576, 0.923, 0.8906, 0.9226, 0.1576, 0.923, 0.8906, 0.9226]
# energy: -13140.522200612366
#  TIME: 2738 milliseconds
# Energy without penalities:-13140.522200612366
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3563, 0.9423, 0.6754, 0.937, 0.3072, 0.9358, 0.913, 0.9363]
#  2.. It: 2 with Of: [0.1576, 0.9204, 0.8839, 0.9205, 0.1569, 0.9204, 0.8877, 0.9202]
#  3.. It: 3 with Of: [0.1579, 0.9232, 0.8908, 0.9228, 0.1579, 0.9232, 0.8908, 0.9228]
#  4.. It: 4 with Of: [0.1576, 0.923, 0.8906, 0.9226, 0.1576, 0.923, 0.8906, 0.9226]
# energy: -13140.522200630661
#  TIME: 2735 milliseconds
# Energy without penalities:-13140.522200630661
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3047, 0.9388, 0.9096, 0.9368, 0.9113, 0.935, 0.1588, 0.9408]
#  2.. It: 2 with Of: [-0.006, 0.9105, 0.8872, 0.9198, 0.8866, 0.9202, 0.0483, 0.9072]
#  3.. It: 3 with Of: [0.1595, 0.9267, 0.8951, 0.9261, 0.8945, 0.9263, 0.1628, 0.9225]
#  4.. It: 4 with Of: [0.1573, 0.9228, 0.8903, 0.9223, 0.8896, 0.9226, 0.1604, 0.9179]
# energy: -13141.7237458982
#  TIME: 2745 milliseconds
# Energy without penalities:-13141.7237458982
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.7354, 0.9293, 0.9027, 0.9314, 0.0582, 0.9187, 0.5844, 0.9196]
#  2.. It: 2 with Of: [0.8846, 0.9209, 0.8879, 0.9204, 0.0484, 0.9038, 0.2522, 0.9191]
#  3.. It: 3 with Of: [0.8906, 0.9234, 0.8913, 0.9231, 0.1567, 0.9235, 0.2504, 0.9226]
#  4.. It: 4 with Of: [0.8886, 0.9218, 0.8892, 0.9215, 0.1564, 0.9219, 0.2484, 0.9209]
# energy: -13138.823398413704
#  TIME: 2718 milliseconds
# Energy without penalities:-13138.823398413704
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0591, 0.924, 0.4326, 0.9285, 0.9048, 0.9349, 0.9033, 0.9319]
#  2.. It: 2 with Of: [0.1532, 0.9203, 0.0836, 0.915, 0.8868, 0.9204, 0.8874, 0.92]
#  3.. It: 3 with Of: [0.1467, 0.9209, 0.1608, 0.9197, 0.8914, 0.924, 0.892, 0.9237]
#  4.. It: 4 with Of: [-0.0056, 0.9151, 0.2485, 0.9223, 0.8901, 0.923, 0.8907, 0.9227]
# energy: -13139.109403835178
#  TIME: 2734 milliseconds
# Energy without penalities:-13139.109403835178
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0603, 0.9115, 0.902, 0.9323, 0.3899, 0.9329, 0.9041, 0.9235]
#  2.. It: 2 with Of: [0.154, 0.9209, 0.8883, 0.9207, 0.37, 0.9212, 0.8883, 0.9206]
#  3.. It: 3 with Of: [0.155, 0.9206, 0.8876, 0.9203, 0.3693, 0.9207, 0.8877, 0.9203]
#  4.. It: 4 with Of: [0.155, 0.9206, 0.8877, 0.9203, 0.3694, 0.9207, 0.8877, 0.9203]
# energy: -13136.772121700018
#  TIME: 2738 milliseconds
# Energy without penalities:-13136.772121700018
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9118, 0.9406, 0.0729, 0.9373, 0.9142, 0.9375, 0.6763, 0.9452]
#  2.. It: 2 with Of: [0.8821, 0.9167, 0.046, 0.901, 0.8822, 0.9167, 0.2356, 0.9131]
#  3.. It: 3 with Of: [0.8912, 0.9239, 0.1602, 0.9194, 0.8912, 0.9239, 0.2374, 0.9221]
#  4.. It: 4 with Of: [0.8888, 0.922, 0.2472, 0.9212, 0.8888, 0.922, 0.2484, 0.9211]
# energy: -13137.079943262503
#  TIME: 2723 milliseconds
# Energy without penalities:-13137.079943262503
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0069, 0.9233, 0.6971, 0.9298, 0.9025, 0.9276, 0.9028, 0.9248]
#  2.. It: 2 with Of: [0.0467, 0.899, 0.6483, 0.9178, 0.8838, 0.918, 0.8844, 0.9176]
#  3.. It: 3 with Of: [0.0476, 0.9004, 0.5137, 0.918, 0.885, 0.9191, 0.8856, 0.9187]
#  4.. It: 4 with Of: [0.1534, 0.9204, 0.5134, 0.9197, 0.8869, 0.9205, 0.8875, 0.9202]
# energy: -13141.13449094422
#  TIME: 2722 milliseconds
# Energy without penalities:-13141.13449094422
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9082, 0.9361, 0.658, 0.934, 0.9065, 0.9376, 0.0665, 0.9378]
#  2.. It: 2 with Of: [0.8828, 0.9173, 0.6466, 0.917, 0.8828, 0.9173, 0.0462, 0.9021]
#  3.. It: 3 with Of: [0.885, 0.9191, 0.649, 0.9189, 0.885, 0.9191, 0.047, 0.905]
#  4.. It: 4 with Of: [0.8848, 0.9189, 0.6488, 0.9187, 0.8848, 0.9189, 0.047, 0.9047]
# energy: -13134.307133075627
#  TIME: 2738 milliseconds
# Energy without penalities:-13134.307133075627
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.0593, 0.9332, 0.9051, 0.933, 0.9115, 0.93, 0.6553, 0.9293]
#  2.. It: 2 with Of: [0.0469, 0.8982, 0.8838, 0.9172, 0.8833, 0.9175, 0.647, 0.9173]
#  3.. It: 3 with Of: [0.0476, 0.9005, 0.8857, 0.9187, 0.8851, 0.9191, 0.6491, 0.9189]
#  4.. It: 4 with Of: [0.0476, 0.9003, 0.8855, 0.9186, 0.8849, 0.919, 0.6489, 0.9187]
# energy: -13134.298654671571
#  TIME: 2733 milliseconds
# Energy without penalities:-13134.298654671571
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.8187, 0.9411, 0.0703, 0.9436, 0.91, 0.9377, 0.9119, 0.9382]
#  2.. It: 2 with Of: [0.6458, 0.9151, 0.0453, 0.8982, 0.88, 0.9151, 0.8806, 0.9146]
#  3.. It: 3 with Of: [0.6487, 0.9194, 0.0471, 0.9052, 0.8853, 0.9193, 0.8859, 0.9189]
#  4.. It: 4 with Of: [0.6482, 0.9191, 0.0469, 0.9047, 0.8848, 0.9189, 0.8854, 0.9185]
# energy: -13134.305599726493
#  TIME: 2793 milliseconds
# Energy without penalities:-13134.305599726493
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.1817, 0.9385, 0.9096, 0.9403, 0.8171, 0.9357, 0.9097, 0.9352]
#  2.. It: 2 with Of: [0.0466, 0.8909, 0.8791, 0.9134, 0.6929, 0.9139, 0.8791, 0.9134]
#  3.. It: 3 with Of: [0.0476, 0.9, 0.8853, 0.9185, 0.6975, 0.919, 0.8853, 0.9185]
#  4.. It: 4 with Of: [0.0473, 0.8993, 0.8848, 0.918, 0.6969, 0.9186, 0.8848, 0.918]
# energy: -13133.487232291536
#  TIME: 2706 milliseconds
# Energy without penalities:-13133.487232291536
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9146, 0.9328, 0.0649, 0.9386, 0.8133, 0.9394, 0.9108, 0.9322]
#  2.. It: 2 with Of: [0.8805, 0.9153, 0.0454, 0.8986, 0.6947, 0.9154, 0.881, 0.9148]
#  3.. It: 3 with Of: [0.8845, 0.9187, 0.0469, 0.9042, 0.6973, 0.9188, 0.8851, 0.9183]
#  4.. It: 4 with Of: [0.8841, 0.9184, 0.0467, 0.9037, 0.6969, 0.9185, 0.8848, 0.918]
# energy: -13133.494731387584
#  TIME: 2728 milliseconds
# Energy without penalities:-13133.494731387584
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.4426, 0.9337, 0.154, 0.94, 0.9112, 0.9387, 0.9133, 0.9371]
#  2.. It: 2 with Of: [0.6442, 0.9191, 0.1561, 0.9131, 0.8846, 0.9186, 0.8852, 0.9182]
#  3.. It: 3 with Of: [0.695, 0.9179, 0.0472, 0.9022, 0.8832, 0.9176, 0.8838, 0.9172]
#  4.. It: 4 with Of: [0.7161, 0.9187, 0.0468, 0.9039, 0.8843, 0.9185, 0.8849, 0.9181]
# energy: -13133.494907845183
#  TIME: 2717 milliseconds
# Energy without penalities:-13133.494907845183
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3897, 0.9297, 0.1534, 0.9327, 0.9083, 0.931, 0.909, 0.9372]
#  2.. It: 2 with Of: [0.6931, 0.9201, 0.244, 0.9188, 0.8858, 0.9195, 0.8864, 0.9192]
#  3.. It: 3 with Of: [0.7127, 0.9161, 0.0472, 0.8988, 0.8809, 0.9159, 0.8815, 0.9154]
#  4.. It: 4 with Of: [0.7163, 0.9186, 0.0468, 0.9037, 0.8842, 0.9184, 0.8848, 0.918]
# energy: -13134.305085781536
#  TIME: 2743 milliseconds
# Energy without penalities:-13134.305085781536
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.1769, 0.9368, 0.9045, 0.934, 0.9043, 0.9312, 0.7391, 0.9309]
#  2.. It: 2 with Of: [0.1492, 0.9146, 0.8807, 0.9147, 0.8801, 0.9152, 0.7129, 0.9148]
#  3.. It: 3 with Of: [0.1511, 0.9167, 0.883, 0.9166, 0.8824, 0.9171, 0.7152, 0.9168]
#  4.. It: 4 with Of: [0.1509, 0.9165, 0.8828, 0.9165, 0.8822, 0.9169, 0.715, 0.9166]
# energy: -13130.733699191813
#  TIME: 2733 milliseconds
# Energy without penalities:-13130.733699191813
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9028, 0.9355, 0.5304, 0.9351, 0.3884, 0.9262, 0.9058, 0.9324]
#  2.. It: 2 with Of: [0.8801, 0.9152, 0.6418, 0.9151, 0.2294, 0.9121, 0.8807, 0.9147]
#  3.. It: 3 with Of: [0.8823, 0.917, 0.7139, 0.9168, 0.1521, 0.9164, 0.8829, 0.9166]
#  4.. It: 4 with Of: [0.8822, 0.9169, 0.88, 0.9167, 0.1509, 0.9165, 0.8828, 0.9165]
# energy: -13130.443872099217
#  TIME: 2838 milliseconds
# Energy without penalities:-13130.443872099217
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.3054, 0.9429, 0.91, 0.9449, 0.9082, 0.9387, 0.9146, 0.9389]
#  2.. It: 2 with Of: [0.1467, 0.9097, 0.8753, 0.9105, 0.8748, 0.9111, 0.8754, 0.9104]
#  3.. It: 3 with Of: [0.047, 0.8938, 0.8809, 0.915, 0.8804, 0.9155, 0.8809, 0.915]
#  4.. It: 4 with Of: [0.0466, 0.8957, 0.8823, 0.9161, 0.8817, 0.9165, 0.8823, 0.9161]
# energy: -13130.425568961084
#  TIME: 2710 milliseconds
# Energy without penalities:-13130.425568961084
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9075, 0.9377, 0.9141, 0.9373, 0.9111, 0.9383, 0.1592, 0.9421]
#  2.. It: 2 with Of: [0.8773, 0.913, 0.8779, 0.9124, 0.8773, 0.913, 0.1506, 0.9058]
#  3.. It: 3 with Of: [0.8802, 0.9153, 0.8808, 0.9148, 0.8802, 0.9153, 0.1532, 0.9086]
#  4.. It: 4 with Of: [0.8799, 0.9151, 0.8805, 0.9146, 0.8799, 0.9151, 0.1529, 0.9083]
# energy: -13127.745997584676
#  TIME: 2714 milliseconds
# Energy without penalities:-13127.745997584676
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9098, 0.9443, 0.4388, 0.9426, 0.9119, 0.9362, 0.9121, 0.9383]
#  2.. It: 2 with Of: [0.8728, 0.9095, 0.1517, 0.8999, 0.8728, 0.9094, 0.8732, 0.9087]
#  3.. It: 3 with Of: [0.8806, 0.9156, 0.1535, 0.9089, 0.8806, 0.9156, 0.8811, 0.9152]
#  4.. It: 4 with Of: [0.8799, 0.9151, 0.1529, 0.9083, 0.8799, 0.9151, 0.8804, 0.9146]
# energy: -13127.745998053733
#  TIME: 2717 milliseconds
# Energy without penalities:-13127.745998053733
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9038, 0.9377, 0.4553, 0.9437, 0.9072, 0.9385, 0.8228, 0.9416]
#  2.. It: 2 with Of: [0.874, 0.9105, 0.2382, 0.9087, 0.8741, 0.9105, 0.873, 0.91]
#  3.. It: 3 with Of: [0.879, 0.9144, 0.2397, 0.9132, 0.879, 0.9144, 0.8796, 0.9139]
#  4.. It: 4 with Of: [0.8786, 0.9141, 0.2392, 0.9129, 0.8786, 0.9141, 0.8791, 0.9135]
# energy: -13125.817827238177
#  TIME: 2725 milliseconds
# Energy without penalities:-13125.817827238177
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9152, 0.9342, 0.9167, 0.9348, 0.9133, 0.9378, 0.1566, 0.9311]
#  2.. It: 2 with Of: [0.8775, 0.913, 0.8781, 0.9124, 0.8775, 0.913, 0.2362, 0.912]
#  3.. It: 3 with Of: [0.8788, 0.9142, 0.8793, 0.9137, 0.8788, 0.9142, 0.2394, 0.913]
#  4.. It: 4 with Of: [0.8786, 0.9141, 0.8792, 0.9136, 0.8786, 0.9141, 0.2392, 0.9129]
# energy: -13125.817827024515
#  TIME: 2731 milliseconds
# Energy without penalities:-13125.817827024515
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9063, 0.9371, 0.9125, 0.9396, 0.9199, 0.9378, 0.4355, 0.9431]
#  2.. It: 2 with Of: [0.8728, 0.9095, 0.8733, 0.9088, 0.873, 0.9095, 0.0741, 0.8995]
#  3.. It: 3 with Of: [0.8817, 0.9166, 0.8823, 0.9161, 0.8818, 0.9166, 0.0757, 0.9104]
#  4.. It: 4 with Of: [0.881, 0.9159, 0.8815, 0.9154, 0.881, 0.9159, 0.075, 0.9096]
# energy: -13126.16571287193
#  TIME: 2729 milliseconds
# Energy without penalities:-13126.16571287193
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9162, 0.9429, 0.7904, 0.9355, 0.3006, 0.9408, 0.9046, 0.9383]
#  2.. It: 2 with Of: [0.8771, 0.9128, 0.8754, 0.9122, 0.3584, 0.9128, 0.8774, 0.9121]
#  3.. It: 3 with Of: [0.8769, 0.9128, 0.8774, 0.9122, 0.3598, 0.9127, 0.8774, 0.9122]
#  4.. It: 4 with Of: [0.8769, 0.9127, 0.8774, 0.9122, 0.3598, 0.9126, 0.8774, 0.9122]
# energy: -13123.277662041335
#  TIME: 2704 milliseconds
# Energy without penalities:-13123.277662041335
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.8194, 0.944, 0.9133, 0.9476, 0.8195, 0.9431, 0.965, 0.9474]
#  2.. It: 2 with Of: [0.6815, 0.9049, 0.8671, 0.904, 0.6815, 0.9049, 0.8681, 0.904]
#  3.. It: 3 with Of: [0.6399, 0.9119, 0.876, 0.9111, 0.6399, 0.9119, 0.876, 0.9111]
#  4.. It: 4 with Of: [0.6398, 0.9125, 0.8768, 0.9117, 0.6398, 0.9125, 0.8768, 0.9117]
# energy: -13121.964293339523
#  TIME: 2707 milliseconds
# Energy without penalities:-13121.964293339523
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9009, 0.9332, 0.5237, 0.9316, 0.902, 0.9237, 0.8979, 0.931]
#  2.. It: 2 with Of: [0.8725, 0.9093, 0.3598, 0.9059, 0.8725, 0.9091, 0.8728, 0.9085]
#  3.. It: 3 with Of: [0.8773, 0.9131, 0.2274, 0.9093, 0.8773, 0.9131, 0.8778, 0.9125]
#  4.. It: 4 with Of: [0.879, 0.9144, 0.3612, 0.9123, 0.879, 0.9144, 0.8795, 0.9138]
# energy: -13126.175622814315
#  TIME: 2725 milliseconds
# Energy without penalities:-13126.175622814315
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9028, 0.9334, 0.5272, 0.9287, 0.9057, 0.9341, 0.901, 0.9238]
#  2.. It: 2 with Of: [0.8723, 0.9091, 0.6336, 0.9087, 0.8724, 0.9091, 0.8727, 0.9083]
#  3.. It: 3 with Of: [0.8729, 0.9097, 0.6367, 0.9092, 0.8729, 0.9097, 0.8734, 0.909]
#  4.. It: 4 with Of: [0.8728, 0.9096, 0.6367, 0.9091, 0.8728, 0.9096, 0.8733, 0.9089]
# energy: -13117.304579516065
#  TIME: 2725 milliseconds
# Energy without penalities:-13117.304579516065
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9065, 0.937, 0.9094, 0.9391, 0.9082, 0.939, 0.5321, 0.9313]
#  2.. It: 2 with Of: [0.8716, 0.9086, 0.8721, 0.9079, 0.8717, 0.9086, 0.6329, 0.9081]
#  3.. It: 3 with Of: [0.873, 0.9097, 0.8734, 0.909, 0.873, 0.9097, 0.6368, 0.9092]
#  4.. It: 4 with Of: [0.8728, 0.9096, 0.8733, 0.9089, 0.8728, 0.9096, 0.6367, 0.9091]
# energy: -13117.304579540929
#  TIME: 2737 milliseconds
# Energy without penalities:-13117.304579540929
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9179, 0.9468, 0.9258, 0.9491, 0.9182, 0.9479, 0.9293, 0.9476]
#  2.. It: 2 with Of: [0.6993, 0.9024, 0.6995, 0.9014, 0.6993, 0.9024, 0.6996, 0.9014]
#  3.. It: 3 with Of: [0.7125, 0.9156, 0.7131, 0.9151, 0.7125, 0.9156, 0.7131, 0.9151]
#  4.. It: 4 with Of: [0.7111, 0.9145, 0.7116, 0.9139, 0.7111, 0.9145, 0.7116, 0.9139]
# energy: -13113.223096109745
#  TIME: 2752 milliseconds
# Energy without penalities:-13113.223096109745
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9046, 0.9415, 0.96, 0.9374, 0.9043, 0.9416, 0.9105, 0.9405]
#  2.. It: 2 with Of: [0.6998, 0.9029, 0.8656, 0.9019, 0.6998, 0.9029, 0.6999, 0.9019]
#  3.. It: 3 with Of: [0.7099, 0.9136, 0.8783, 0.9129, 0.7099, 0.9136, 0.7105, 0.913]
#  4.. It: 4 with Of: [0.7088, 0.9127, 0.8771, 0.9119, 0.7088, 0.9127, 0.7092, 0.912]
# energy: -13122.438128239708
#  TIME: 2720 milliseconds
# Energy without penalities:-13122.438128239708
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9084, 0.9314, 0.91, 0.9388, 0.4612, 0.9301, 0.9046, 0.9388]
#  2.. It: 2 with Of: [0.873, 0.9095, 0.8734, 0.9089, 0.6811, 0.9101, 0.8733, 0.9089]
#  3.. It: 3 with Of: [0.8721, 0.9091, 0.8725, 0.9083, 0.6849, 0.9093, 0.8725, 0.9083]
#  4.. It: 4 with Of: [0.8721, 0.9091, 0.8725, 0.9083, 0.685, 0.9093, 0.8725, 0.9083]
# energy: -13116.265265758046
#  TIME: 2730 milliseconds
# Energy without penalities:-13116.265265758046
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.91, 0.9419, 0.9192, 0.947, 0.9118, 0.9417, 0.8024, 0.9402]
#  2.. It: 2 with Of: [0.8666, 0.9047, 0.867, 0.9038, 0.8667, 0.9047, 0.7001, 0.9038]
#  3.. It: 3 with Of: [0.8724, 0.9093, 0.8728, 0.9085, 0.8724, 0.9093, 0.7049, 0.9086]
#  4.. It: 4 with Of: [0.8718, 0.9088, 0.8722, 0.9081, 0.8718, 0.9088, 0.7044, 0.9082]
# energy: -13115.8585771046
#  TIME: 2720 milliseconds
# Energy without penalities:-13115.8585771046
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.899, 0.9333, 0.9, 0.9294, 0.8954, 0.9249, 0.7296, 0.9334]
#  2.. It: 2 with Of: [0.8692, 0.9068, 0.8695, 0.9059, 0.8692, 0.9066, 0.7016, 0.906]
#  3.. It: 3 with Of: [0.8721, 0.9091, 0.8725, 0.9083, 0.8721, 0.9091, 0.7047, 0.9084]
#  4.. It: 4 with Of: [0.8718, 0.9088, 0.8722, 0.9081, 0.8718, 0.9088, 0.7044, 0.9082]
# energy: -13115.858576804014
#  TIME: 2738 milliseconds
# Energy without penalities:-13115.858576804014
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9119, 0.9438, 0.9179, 0.9456, 0.9184, 0.9422, 0.9133, 0.9469]
#  2.. It: 2 with Of: [0.8646, 0.9031, 0.8647, 0.9021, 0.8647, 0.9031, 0.8647, 0.9021]
#  3.. It: 3 with Of: [0.8699, 0.9073, 0.8702, 0.9065, 0.8699, 0.9073, 0.8702, 0.9065]
#  4.. It: 4 with Of: [0.8693, 0.9069, 0.8696, 0.9061, 0.8693, 0.9069, 0.8696, 0.9061]
# energy: -13112.34136626929
#  TIME: 2705 milliseconds
# Energy without penalities:-13112.34136626929
# Progress: 0.0%
# 0.. Rand seed: 1
#  1.. It: 1 with Of: [0.9045, 0.9276, 0.9056, 0.932, 0.8981, 0.9305, 0.7273, 0.9297]
#  2.. It: 2 with Of: [0.8692, 0.9065, 0.8695, 0.9058, 0.869, 0.9066, 0.8662, 0.906]
#  3.. It: 3 with Of: [0.8695, 0.907, 0.8698, 0.9062, 0.8695, 0.907, 0.8697, 0.9062]
#  4.. It: 4 with Of: [0.8694, 0.9069, 0.8697, 0.9061, 0.8694, 0.9069, 0.8697, 0.9061]
# energy: -13112.341365877475
#  TIME: 2717 milliseconds
# Energy without penalities:-13112.341365877475
# 80-element Vector{Any}:
#  4.3774144716288986e-5
#  4.1102755158603524e-5
#  4.5779894657059546e-5
#  4.264135675654276e-5
#  4.485076452690312e-5
#  5.684785831836835e-5
#  5.963508219298237e-5
#  3.9463928313332866e-5
#  6.736582345684225e-5
#  5.568927372251461e-5
#  ⋮
#  4.251851390129224e-5
#  4.0819011612533184e-5
#  5.733227064863141e-5
#  5.193022102131948e-5
#  4.241490704004475e-5
#  4.337368940893094e-5
#  4.2258396281373365e-5
#  5.536521421891138e-5
#  5.527490657216989e-5

# %%
fig = Figure()
ax = Axis(fig[1,1], xlabel = "ν", ylabel = "DOS [Å^-2]")
scatter!(ax, fillings, [m for m in mydos])
fig

# %% [markdown]
# #### Self-consistent integral

# %%
magneto_conductivity(:x, :x, :x, p, sd, T = 1000, τ = 200, evals = 400,
    Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# -3.0450042949323292e-5

# %%
it = 30
simportedqah.ns[it]
# Out:
# 0.5829145728643216

# %%
magneto_conductivity(:x, :x, :x, ParamsHF(pimported, μ = simportedqah.mus[it]), diagm(simportedqah.ofmats[it]),
  T = 0.1, τ = 200, evals = 40000, Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# 6.036456071800199e-5

# %% [markdown]
# ##### Convergence tests

# %%
conv_xs = [2^l for l in 1:12]
conv_list = [magneto_conductivity(:x, :x, :x, p, sd, T = 10, τ = 200, evals = it,
    Ω_contr = true, omm_contr = false) for it in conv_xs]
# Out:
# 12-element Vector{Float64}:
#  4.3976481709434515e-9
#  4.3976481709434515e-9
#  4.3976481709434515e-9
#  4.3976481709434515e-9
#  3.28747618978529e-9
#  1.6646384363067327e-9
#  1.3534974593952797e-9
#  1.7306071274265184e-9
#  3.4239936305571604e-9
#  4.47851131761299e-9
#  4.2726544180788134e-9
#  4.270490624449422e-9

# %%
fig_conv = Figure(size = (600,600))
ax = Axis(fig_conv[1,1], xscale = log2)
scatter!(ax, conv_xs, conv_list)
lines!(ax, conv_xs, conv_list)

fig_conv

# %% [markdown]
# conv_xs = [2^l for l in 1:14]
# conv_list = [magneto_conductivity(:x, :x, :x, p, of0, T = 2, τ = 1e-5, evals = it) for it in conv_xs]

# %% [markdown]
# ###### Non interacting MC

# %%
magneto_conductivity(:x,:x,:x, p, of0, T = 2, τ = 1e-5, evals = 1000)
# Out:
# -8.087497872943983e-12

# %% [markdown]
# ## Import selfconsistent data

# %% [markdown]
# #### Load data

# %%
function provide_folder_get_observables_atlas_reshuffled(folder, rs = "rs")
    str = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/cluster_temp/exportdata"* "/" * string(folder)
       es_path = str * "/joined_es_"*rs*".csv"
       mus_path = str * "/joined_mus_"*rs*".csv"
       ns_path = str * "/joined_ns_"*rs*".csv"
       ofmats_path = str * "/joined_ofmats_"*rs*".csv"
       s = return_variables_reshuffled(es_path,mus_path, ns_path, ofmats_path )
       Self_consistent_data(s[1], s[2], s[3], s[4])
end
# Out:
# provide_folder_get_observables_atlas_reshuffled (generic function with 2 methods)

# %%
folder = 2281379#2281278
simportedvp = provide_folder_get_observables_atlas_reshuffled(folder,  "vp")
simportedqah = provide_folder_get_observables_atlas_reshuffled(folder,  "qah")
# Out:
# UndefVarError: `provide_folder_get_observables_atlas_reshuffled` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/MR.ipynb:2

# %%
l = readparams(folder);
pimported = ParamsHF(paramsHF(1.05, 1,  1),
    μ = 0,
    nf = l.nf[1],
    λ = l.λ[1],
    M = l.M[1],
    v = l.v[1],
    vp = l.vp[1],
    γ =l.γ[1],
    sigmaz = l.sigmaz[1],
    sigmazlayerz = l.sigmazlayerz[1],
    U1 = l.U1[1],
    U2 = l.U2[1],
    J = 0*l.J[1],
    VP =l.VP[1],
    twovalleystwospins= l.twovalleystwospins[1]);

# %%
l.vp
# Out:
# 1-element Vector{Float64}:
#  2000.0

# %% [markdown]
# #### Bands for the QAH and VH states

# %%
filling = 3
itn = argmin(abs.(simportedvp.ns .- filling))
# Out:
# 150

# %%
println("ν=", simportedvp.ns[itn])
println(" nf =", round.(simportedvp.ofmats[itn],digits = 2))
hf_plotbands(ParamsHF(pimported, μ = simportedvp.mus[itn]), diagm(simportedvp.ofmats[itn]), kpoints = 101, res = (600,400), ylims = [-15,15])
# Out:
# ν=2.9949748743718594
#  nf =[0.87, 0.89, 0.49, 0.89, 0.87, 0.89, 0.17, 0.88]

# %%
hf_plotbands(ParamsHF(pimported, μ = 0), diagm(simportedqah.ofmats[itn]), kpoints = 101, res = (600,400), ylims = [-15,15])

# %% [markdown]
# ### Magnetorresistance over imported data

# %%
magneto_conductivity(:x, :x, :x, ParamsHF(pimported, μ = simportedvp.mus[itn]), 
diagm(simportedvp.ofmats[itn]), T = 0.1, τ = 200, evals = 100000, Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# -0.0005542616966999506

# %%
magneto_conductivity(:x, :x, :x, ParamsHF(pimported, μ = simportedqah.mus[itn]), 
diagm(simportedqah.ofmats[itn]), T = 0.1, τ = 200, evals = 100000, Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# 0.0001382083743173613

# %% [markdown]
# ##### Valley Hall

# %%
ns, mcvh = mc_sweep(:x, :x, :x, pimported, simportedvp; 
    T = 1, τ = 200, evals = 5120, Ω_contr = true, omm_contr = true, fermi_surface = false)

# %%
fig = Figure()
ax = Axis(fig[1,1], xlabel = "ν", ylabel = "σ_xxx [e²/h 1/T]", title = "VH")
scatter!(ax, [n for n in ns], [m for m in mcvh])
fig

# %% [markdown]
# ##### Anomalous Hall

# %%
ns, mcqah = mc_sweep(:x, :x, :x, pimported, simportedqah; 
    T = 1, τ = 200, evals = 5120, Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# progress: 0.005 |  val: 9.240846214892541e-5
# progress: 0.01 |  val: -0.00010580562941458657
# progress: 0.015 |  val: -0.00012223536397734815
# progress: 0.02 |  val: -0.0001366963031208039
# progress: 0.025 |  val: -0.00015111870241575184
# progress: 0.03 |  val: -0.00016506966941396466
# progress: 0.035 |  val: -0.00017331935024200173
# progress: 0.04 |  val: -0.00016360042496774344
# progress: 0.045 |  val: -4.955604963553906e-5
# progress: 0.05 |  val: -3.100449549275924e-5
# progress: 0.055 |  val: -7.372509781567268e-5
# progress: 0.06 |  val: 0.00032138602209528985
# progress: 0.065 |  val: 5.302311901773812e-6
# progress: 0.07 |  val: -1.4453937888636079e-5
# progress: 0.075 |  val: -0.00012510069339952506
# progress: 0.08 |  val: 7.734687240872613e-5
# progress: 0.085 |  val: 1.3832529443622704e-5
# progress: 0.09 |  val: -7.346057731298076e-5
# progress: 0.095 |  val: 0.00020511560888868924
# progress: 0.1 |  val: 3.4395859377120246e-5
# progress: 0.105 |  val: 0.00029736164116968554
# progress: 0.11 |  val: 0.00012336896108984158
# progress: 0.115 |  val: 0.00018325138335180882
# progress: 0.12 |  val: 4.739760864177454e-5
# progress: 0.125 |  val: 0.00013841667966781333
# progress: 0.13 |  val: 9.651617845196918e-5
# progress: 0.135 |  val: 6.163305598046512e-5
# progress: 0.14 |  val: 7.595771607059269e-5
# progress: 0.145 |  val: 6.216021579790154e-5
# progress: 0.15 |  val: -7.890360940328382e-5
# progress: 0.155 |  val: 4.435092013386577e-5
# progress: 0.16 |  val: 7.726875405815143e-5
# progress: 0.165 |  val: 6.918656972990496e-5
# progress: 0.17 |  val: 0.00011728742348043293
# progress: 0.175 |  val: 0.00011924251061160537
# progress: 0.18 |  val: 0.00012926398301855502
# progress: 0.185 |  val: 3.742789868194133e-5
# progress: 0.19 |  val: 0.0001132276800240276
# progress: 0.195 |  val: 6.264465981220337e-5
# progress: 0.2 |  val: 6.153210298836929e-5
# progress: 0.205 |  val: 7.152839271020113e-5
# progress: 0.21 |  val: 3.81854119048825e-5
# progress: 0.215 |  val: 6.433116949391633e-5
# progress: 0.22 |  val: -6.36902858381097e-5
# progress: 0.225 |  val: 0.00016590169280646352
# progress: 0.23 |  val: 4.393517560529611e-5
# progress: 0.235 |  val: 3.7211978503449376e-5
# progress: 0.24 |  val: 2.0981199276778392e-5
# progress: 0.245 |  val: 9.154998464421159e-6
# progress: 0.25 |  val: 5.330317679242361e-7
# progress: 0.255 |  val: -2.6517901499846528e-5
# progress: 0.26 |  val: -2.827615564509279e-5
# progress: 0.265 |  val: -2.867947778160544e-5
# progress: 0.27 |  val: -2.8344323899132425e-5
# progress: 0.275 |  val: -2.7366630440955515e-5
# progress: 0.28 |  val: -2.6882202986804043e-5
# progress: 0.285 |  val: -2.245258756284674e-5
# progress: 0.29 |  val: -2.0518279417610315e-5
# progress: 0.295 |  val: -2.2380931170630585e-5
# progress: 0.3 |  val: -1.5426508432146253e-5
# progress: 0.305 |  val: -9.004062102125777e-6
# progress: 0.31 |  val: -6.292126637130006e-6
# progress: 0.315 |  val: -3.2981076535783845e-6
# progress: 0.32 |  val: 1.0546901349657396e-5
# progress: 0.325 |  val: 2.521040800284701e-5
# progress: 0.33 |  val: 3.285196608571621e-5
# progress: 0.335 |  val: 2.6940128698283628e-5
# progress: 0.34 |  val: 3.0958305175698105e-5
# progress: 0.345 |  val: 5.052881508112392e-5
# progress: 0.35 |  val: 9.726106885950569e-5
# progress: 0.355 |  val: 5.202423888524787e-5
# progress: 0.36 |  val: 8.875503012412023e-5
# progress: 0.365 |  val: 0.00011201938608758966
# progress: 0.37 |  val: 0.00010176087763702203
# progress: 0.375 |  val: 0.00011649944872552852
# progress: 0.38 |  val: 0.00011009673331995586
# progress: 0.385 |  val: 9.146971994641446e-5
# progress: 0.39 |  val: 1.7854427967448422e-5
# progress: 0.395 |  val: 9.575939058764589e-5
# progress: 0.4 |  val: 9.671087165527553e-5
# progress: 0.405 |  val: 9.786918562448962e-5
# progress: 0.41 |  val: 7.052844679726662e-5
# progress: 0.415 |  val: 7.512416003766757e-5
# progress: 0.42 |  val: 0.00011612776705293638
# progress: 0.425 |  val: 9.42593692346933e-5
# progress: 0.43 |  val: 0.00011746516416201215
# progress: 0.435 |  val: 8.43731120644642e-5
# progress: 0.44 |  val: 0.00012028290404050584
# progress: 0.445 |  val: 6.273027265349462e-5
# progress: 0.45 |  val: 7.208414958911479e-5
# progress: 0.455 |  val: 4.659611788684078e-5
# progress: 0.46 |  val: 4.042423920960734e-5
# progress: 0.465 |  val: 4.918376868295989e-5
# progress: 0.47 |  val: -0.00013541266934288324
# progress: 0.475 |  val: 3.070897245669874e-5
# progress: 0.48 |  val: 4.275476363137522e-5
# progress: 0.485 |  val: 4.5433138537550975e-5
# progress: 0.49 |  val: 9.239075146515779e-5
# progress: 0.495 |  val: 7.69573923467145e-5
# progress: 0.5 |  val: 0.00012242909729179828
# progress: 0.505 |  val: 0.00011629372258122128
# progress: 0.51 |  val: 0.00013048613305862127
# progress: 0.515 |  val: 5.782103793081886e-5
# progress: 0.52 |  val: 8.192314566634823e-5
# progress: 0.525 |  val: 7.707962132203961e-6
# progress: 0.53 |  val: 9.458892083463005e-5
# progress: 0.535 |  val: 2.7252518068927292e-5
# progress: 0.54 |  val: 7.302251597614368e-5
# progress: 0.545 |  val: 7.576060325870217e-5
# progress: 0.55 |  val: 6.838332340989903e-5
# progress: 0.555 |  val: 0.00013847112233118835
# progress: 0.56 |  val: 0.00011176122116875611
# progress: 0.565 |  val: 0.00013640701055304754
# progress: 0.57 |  val: 0.00014736075546377723
# progress: 0.575 |  val: 0.0001843040071835613
# progress: 0.58 |  val: 0.00014303208868330053
# progress: 0.585 |  val: 0.00011801704332321876
# progress: 0.59 |  val: 0.00013803093139272334
# progress: 0.595 |  val: 0.0001344508771581935
# progress: 0.6 |  val: 0.00014795527014967812
# progress: 0.605 |  val: 0.0001252949218894755
# progress: 0.61 |  val: 0.0001154954532180635
# progress: 0.615 |  val: 0.00012794235867992254
# progress: 0.62 |  val: 0.00010914951947138681
# progress: 0.625 |  val: 8.090629443559697e-5
# progress: 0.63 |  val: 9.455733086950104e-5
# progress: 0.635 |  val: 0.00010698751549143182
# progress: 0.64 |  val: 0.00012459540982319832
# progress: 0.645 |  val: 5.3277454731112674e-5
# progress: 0.65 |  val: 6.896147686363351e-5
# progress: 0.655 |  val: 9.594735852541367e-5
# progress: 0.66 |  val: 5.9455794225838206e-5
# progress: 0.665 |  val: 4.918944844473316e-5
# progress: 0.67 |  val: 6.549652089750818e-5
# progress: 0.675 |  val: 4.4729372609716124e-5
# progress: 0.68 |  val: 3.880271566605988e-6
# progress: 0.685 |  val: 3.701771819959582e-5
# progress: 0.69 |  val: 1.7182765284915197e-5
# progress: 0.695 |  val: 3.687737995258069e-5
# progress: 0.7 |  val: 3.737967708957816e-5
# progress: 0.705 |  val: -2.7135737990472078e-6
# progress: 0.71 |  val: 0.00013873791230325987
# progress: 0.715 |  val: -8.356090730143982e-6
# progress: 0.72 |  val: -1.123678369446314e-5
# progress: 0.725 |  val: 4.967511787639347e-5
# progress: 0.73 |  val: 3.3658251995150274e-5
# progress: 0.735 |  val: 4.908559358133454e-5
# progress: 0.74 |  val: -5.9529050405739375e-6
# progress: 0.745 |  val: 0.0001613486575543869
# progress: 0.75 |  val: 0.00011373038907575688
# progress: 0.755 |  val: 0.00015505295031937783
# progress: 0.76 |  val: 0.00014815842562524182
# progress: 0.765 |  val: 9.392137283357048e-5
# progress: 0.77 |  val: 0.00015971179156402357
# progress: 0.775 |  val: 0.0001804912949071382
# progress: 0.78 |  val: 0.00019270249981943765
# progress: 0.785 |  val: 0.0001848766248526446
# progress: 0.79 |  val: 0.0003038138327106804
# progress: 0.795 |  val: 0.00020431158480457837
# progress: 0.8 |  val: 0.00017535742474111165
# progress: 0.805 |  val: 0.00017440932075327105
# progress: 0.81 |  val: 7.729999687332277e-5
# progress: 0.815 |  val: 8.652235039255077e-5
# progress: 0.82 |  val: 7.654028874873561e-5
# progress: 0.825 |  val: 4.304285427432e-5
# progress: 0.83 |  val: 0.0005904870739955978
# progress: 0.835 |  val: 2.552908063743525e-5
# progress: 0.84 |  val: 1.5121914468906403e-5
# progress: 0.845 |  val: 2.3262871517740352e-5
# progress: 0.85 |  val: 7.075424468769015e-5
# progress: 0.855 |  val: 4.170512394567027e-5
# progress: 0.86 |  val: 2.4732290116784745e-5
# progress: 0.865 |  val: -2.2136593727868945e-6
# progress: 0.87 |  val: -1.7197344931655455e-5
# progress: 0.875 |  val: 9.651089917700431e-6
# progress: 0.88 |  val: -4.336331264302003e-5
# progress: 0.885 |  val: -3.267056518003109e-6
# progress: 0.89 |  val: -6.135318848371952e-6
# progress: 0.895 |  val: -3.8445134955907484e-6
# progress: 0.9 |  val: 5.8654942406678985e-6
# progress: 0.905 |  val: -3.0506432361496197e-6
# progress: 0.91 |  val: 7.330872739111596e-6
# progress: 0.915 |  val: -3.377431717882558e-6
# progress: 0.92 |  val: -2.28256073037003e-6
# progress: 0.925 |  val: -2.127405037729623e-6
# progress: 0.93 |  val: -1.9273263082306753e-6
# progress: 0.935 |  val: -4.755945940367273e-6
# progress: 0.94 |  val: -1.1754432617720527e-5
# progress: 0.945 |  val: -1.4768594859164122e-6
# progress: 0.95 |  val: -1.456294833797449e-6
# progress: 0.955 |  val: -9.546756245126057e-7
# progress: 0.96 |  val: -5.951759003361987e-6
# progress: 0.965 |  val: -1.0643351660751598e-6
# progress: 0.97 |  val: 3.921431528934951e-7
# progress: 0.975 |  val: -0.00010833996446551602
# progress: 0.98 |  val: -4.369914274631802e-6
# progress: 0.985 |  val: -5.127563850686262e-6
# progress: 0.99 |  val: -3.2325481603070954e-7
# progress: 0.995 |  val: 0.0001757660881353476
# progress: 1.0 |  val: -3.084433688649997e-6
# ([0.0, 0.020100502512562814, 0.04020100502512563, 0.06030150753768844, 0.08040201005025126, 0.10050251256281408, 0.12060301507537688, 0.1407035175879397, 0.16080402010050251, 0.18090452261306533  …  3.819095477386935, 3.8391959798994977, 3.85929648241206, 3.879396984924623, 3.899497487437186, 3.919597989949749, 3.9396984924623117, 3.959798994974874, 3.979899497487437, 4.0], Any[9.240846214892541e-5, -0.00010580562941458657, -0.00012223536397734815, -0.0001366963031208039, -0.00015111870241575184, -0.00016506966941396466, -0.00017331935024200173, -0.00016360042496774344, -4.955604963553906e-5, -3.100449549275924e-5  …  -9.546756245126057e-7, -5.951759003361987e-6, -1.0643351660751598e-6, 3.921431528934951e-7, -0.00010833996446551602, -4.369914274631802e-6, -5.127563850686262e-6, -3.2325481603070954e-7, 0.0001757660881353476, -3.084433688649997e-6])

# %%
fig = Figure()
ax = Axis(fig[1,1], xlabel = "ν", ylabel = "σ_xxx [e²/h 1/T]", title = "QAH")
scatter!(ax, [n for n in ns], [m for m in mcqah])
lines!(ax, [n for n in ns], [m for m in mcqah])
fig

# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/figures_arxiv_v1.jl")
lat_fig2(folder)

# %% [markdown]
# ### B-independent \sigma_xx conductivity

# %%
in_plane_bindependent_conductivity(:x, ParamsHF(pimported, μ = simportedvp.mus[it]), 
    diagm(simportedvp.ofmats[it]), T = 10, τ = 200, evals = 4000)
# Out:
# -0.5293577074816685

# %% [markdown]
# ### sigma_xxx/sigma_xx [1/T]

# %%
magneto_conductivity(:x, :x, :x, ParamsHF(pimported, μ = simportedvp.mus[it]), 
diagm(simportedvp.ofmats[it]), T = 10, τ = 200,
    evals = 4000, Ω_contr = true, omm_contr = true, fermi_surface = false)
# Out:
# -1.1060341354207312e-5

# %%
mc_ratio(:x, :x, :x, ParamsHF(pimported, μ = simportedvp.mus[it]), diagm(simportedvp.ofmats[it]),
  T = 10, τ = 200, evals = 4000, Ω_contr = true, omm_contr = true)
# Out:
# (-1.1060341354207312e-5, -0.5293577074816685, 2.0893889326416066e-5)

# %% [markdown]
# ## Atlas Calculations

# %% [markdown]
# ### Substrate

# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_module.jl")
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_read_atlas")
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_atlas_plotters.jl")
# Out:
# plot_mc_atlas_rat (generic function with 3 methods)

# %%
# PID = "MR2604173-2281278"
# PID = "MR2604409-2281278"
# PID = "MR2605392-2281278"
# PID = "MR2606874-2281278"
# PID = "MR2607521-2281278"
#PID = "MR2608158-2281278"
# PID = "MR2604408-2281278"
# PID = "MR2604411-2281278"
# PID = "MR2606873-2281278"
# PID = "MR2607520-2281278"
# PID = "MR2608156-2281278" # T = 1 100000
#  PID2 = "MR2608150-2281278"  # QAH 100000 1K  T = 1 100000
PID = "MR2608157-2281278" # vp 100000 5K
PID2= "MR2608158-2281278"# qah 100000 5K
# PID ="MR2613437-2281278"
# PID2 = "MR2613539-2281278"
# No substrate
PID = "MR2620964-2618196" #1K
# Out:
# "MR2620964-2618196"

# %%
plot_mc_atlas(PID, ylims = (-10,10))

# %%
twoplot_mc_atlas(PID, PID2, ylims = (-4,4))

# %%
plot_mc_atlas_rat(PID, ylims = (-5.2,5.2))

# %%
nlist, mrlist = reshapemrdata(PID)
# Out:
# (Any[1.9899497487437185, 2.0100502512562812, 2.030150753768844, 2.050251256281407, 2.07035175879397, 2.090452261306533, 2.1105527638190953, 2.130653266331658, 2.150753768844221, 2.170854271356784  …  1.8090452261306533, 1.829145728643216, 1.849246231155779, 1.8693467336683418, 1.8894472361809045, 1.9095477386934674, 1.92964824120603, 1.949748743718593, 1.9698492462311559, 0.16080402010050251], Any[-4.731273215695355e-5, -5.8934934060623764e-5, -7.261906434448887e-5, -7.13726111551266e-5, -7.016808546579355e-5, -7.368425725428547e-5, -7.239442278621462e-5, -6.9464254898198e-5, -7.023908481289946e-5, -7.140725571776371e-5  …  7.382006955394195e-5, 7.371958852362402e-5, 7.18421182586218e-5, 8.044026368970996e-5, 7.612761454854505e-5, 7.011592941318045e-5, 5.3822364242735265e-5, 2.078415754409314e-5, -1.5466893538700185e-5, 0.00016247016754344554], Any[-0.7873630543356264, -0.7966997639011911, -0.8069806365669476, -0.8189603254078007, -0.8372674564693322, -0.8459600682237678, -0.8559563714947159, -0.870465282623147, -0.9028784957603613, -0.8958687841728334  …  -0.864714128403777, -0.8538935105733411, -0.84444376896444, -0.8341311878704037, -0.8232230785613625, -0.812019821681221, -0.8002059926962067, -0.7889383468090214, -0.788202798169207, -1.9290618107361202], Any[6.009010950720292e-5, 7.397383146197724e-5, 8.998860821918166e-5, 8.715026716292594e-5, 8.380605853437192e-5, 8.710134203969896e-5, 8.457723453801236e-5, 7.980129280844778e-5, 7.779461482660238e-5, 7.97072707290442e-5  …  -8.536933436049025e-5, -8.633346853066666e-5, -8.507626072808066e-5, -9.64359861607377e-5, -9.247507331983837e-5, -8.634755894013908e-5, -6.726063630364312e-5, -2.634446357964188e-5, 1.9622987351257586e-5, -8.42223751666349e-5])

# %% [markdown]
# ### Without substrate

# %%
function substrateoff(PID::Array)
    s = [substrateyesornot(p) for p in PID]
    numbers[findall(x-> x == false, s)]
end
substrateyesornot(PID::Number) = substrateyesornot(string(PID))
function substrateyesornot(PID::String)
    file = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/MRDATA/" * PID *"/1/" * "params.csv"
    if isfile(file)
        l = CSV.read(file, DataFrame)
        if :sigmaz in names(l) && :sigmazlayerz in names(l)
            return ifelse(abs(l.sigmaz[1] + l.sigmazlayerz[1]) > 1e-3, true, false)
        else 
            return ifelse(abs(l.sigmaz[1]) > 0, true, false)
        end
    else nothing end
end

readparams(PID::Number) = readparams(string(PID))
function readparams(PID::String)
    file = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/MRDATA/" * PID *"/1/" * "params.csv"
    if isfile(file)
        l = CSV.read(file, DataFrame)
        return l
    end
end
# Out:
# readparams (generic function with 2 methods)

# %%
foldernosubstrate = 2281278#2618196
l = readparams(foldernosubstrate);
l
# Out:
# 1×23 DataFrame
#  Row │ J        KIVC   M        U1       U2       VP    c2ybreakingmass  n     ⋯
#      │ Float64  Bool   Float64  Float64  Float64  Bool  Float64          Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1.0  false      5.0      5.0      0.0  true              0.0      0 ⋯
#                                                               16 columns omitted

# %%
pnosubstrate = ParamsHF(paramsHF(1.05, 1,  1),
    μ = l.μ[1],
    nf = l.nf[1],
    λ = l.λ[1],
    M = l.M[1],
    v = l.v[1],
    vp = l.vp[1],
    γ =l.γ[1],
    sigmaz = l.sigmaz[1],
    sigmazlayerz = l.sigmazlayerz[1],
    U1 = l.U1[1],
    U2 = l.U2[1],
    J = l.J[1],
    VP =l.VP[1],
    twovalleystwospins= l.twovalleystwospins[1]);

# %%
simportedvpnosubs = provide_folder_get_observables_atlas_reshuffled(foldernosubstrate,  "vp")
simportedqahnosubs = provide_folder_get_observables_atlas_reshuffled(foldernosubstrate,  "qah")
# Out:
# Self_consistent_data([[0.09177345774687988, 0.9082266953889119, 0.09177332560351777, 0.9082265632458201, 0.09177345774707828, 0.9082266953886995, 0.09177332560324447, 0.90822656324608], [0.09511348277570118, 0.9082511047894717, 0.09488496101520044, 0.9082363274508053, 0.09506482891973579, 0.9082485860070545, 0.09488496101520041, 0.9082363274508], [0.09837451965982014, 0.9082578457346432, 0.09819466351798244, 0.9082466677698788, 0.09837451965980154, 0.9082578457346596, 0.09819466212611173, 0.908246668566111], [0.10245915358429471, 0.9083252464279664, 0.10138957737766345, 0.9082700970840478, 0.1014245880034912, 0.9082721917421305, 0.10138957737766344, 0.908270097084047], [0.1063219445813836, 0.908357447941392, 0.10450540358549186, 0.9082591487666652, 0.10465143137966329, 0.9082700749993093, 0.10450540358549182, 0.908259148766665], [0.10919545986212188, 0.9083505993834553, 0.10789113601393205, 0.9082876665175774, 0.10893827608404896, 0.9083380869167671, 0.107891136013932, 0.908287666517577], [0.11845355709990406, 0.9086489725171853, 0.10952567822992254, 0.90822314692232, 0.1098145973222243, 0.908233737302162, 0.10952567822992247, 0.90822314692232], [0.13858745142043616, 0.9093613739994015, 0.10779763987336953, 0.9079443780588354, 0.1079373053211103, 0.9079430696322858, 0.10779763987336953, 0.907944378058835], [0.2154612755655049, 0.9110117306547377, 0.09002920161538991, 0.9064169933144123, 0.09002801595997058, 0.9064159197917031, 0.09002920161539, 0.906416993314412], [0.23128576983496688, 0.911125877427515, 0.08981405086281766, 0.9061831718832066, 0.08981388196289124, 0.9061829972415142, 0.08981405086278255, 0.906183171883245]  …  [0.8583648768136997, 0.8786889062869946, 0.8583641692351479, 0.8786883099668824, 0.8583648768136972, 0.8786889062869954, 0.6812340514076876, 0.878580899856433], [0.8580050377866519, 0.8783918119473452, 0.8580050288372784, 0.878391833479418, 0.858005037786645, 0.8783918119473468, 0.699997147091482, 0.878305019508665], [0.8576348679625427, 0.8780864317178356, 0.8576348931892713, 0.8780864253593691, 0.8576348679625396, 0.8780864317178365, 0.7191895869816571, 0.878023799417943], [0.8572274049043805, 0.8777500688700604, 0.8572241077017898, 0.8777473544461614, 0.8572274049033496, 0.8777500688702878, 0.7403830202572792, 0.877709341587372], [0.8568590042235879, 0.8774457796729456, 0.8568589927422301, 0.8774457991460152, 0.8568590042235843, 0.877445779672947, 0.7593810079998794, 0.87742960100555], [0.8565005029251016, 0.8771498075328124, 0.8565005146063442, 0.8771497881374717, 0.8565005029247001, 0.8771498075329014, 0.7778792375501451, 0.877152118952663], [0.8561296048614923, 0.8768435154216533, 0.8561295937539933, 0.8768435356187301, 0.8561296048613428, 0.876843515421686, 0.7969824807640586, 0.876857526471811], [0.8557433974976799, 0.8765245828996274, 0.85574338630191, 0.8765246031169082, 0.8557433974973523, 0.8765245828996978, 0.8168347779825809, 0.876542970188091], [0.8553765847290887, 0.8762218283582879, 0.8553765955926255, 0.8762218078249482, 0.8553765847290888, 0.8762218283582875, 0.8356209514623076, 0.876235949753168], [0.8549979768597685, 0.8759090615080275, 0.8549979880582086, 0.8759090411304669, 0.8549979768597681, 0.8759090615080275, 0.8549979880582081, 0.875909041130466]], [-3.5651296333820013, 3.6208477864575888, 3.6794229185237852, 3.734536322176679, 3.794797771983223, 3.8532822029968057, 3.9094908041233367, 3.9671231970179406, 4.003530524932407, 4.0355623754790715  …  14.83141198392037, 14.837184167463594, 14.84449974140892, 14.853682812218496, 14.865537218156877, 14.880577488160661, 14.895469670208655, 14.912029539587696, 14.929261875222458, 14.947693039291263], [-8721.97533891634, -8721.997839480558, -8722.013944662387, -8722.046709802082, -8722.05451738995, -8722.078993119256, -8722.096057009103, -8722.125422012004, -8722.143454258106, -8722.166453108766  …  -8708.710952642143, -8708.5354402061, -8708.35689889171, -8708.159839785825, -8707.985325639014, -8707.811625598957, -8707.636415681, -870 ...

# %%
pos = findclosest(2, simportedvpnosubs.ns);
round.(simportedvpnosubs.ofmats[itn]', digits = 2)
# Out:
# 1×8 Matrix{Float64}:
#  0.89  0.9  0.2  0.9  0.2  0.9  0.32  0.9

# %%
itn = pos
hf_plotbands(ParamsHF(pnosubstrate, μ = simportedvpnosubs.mus[itn]), 
simportedvpnosubs.ofmats[itn], kpoints = 101, res = (600,400), ylims = [-15,15])

# %%
ParamsHF(pnosubstrate, μ = 0*simportedvpnosubs.mus[itn]);

# %%
t1 = tauz(simportedqahnosubs)
t2 = tauz(simportedvpnosubs)
fig = Figure()
ax = Axis(fig[1,1]) 
lines!(ax, simportedqahnosubs.ns, t1, label = "qah")
lines!(ax, simportedvpnosubs.ns, t2, label = "vp")
axislegend(ax, position = :lt)
fig

# %%
function C2x(s::Self_consistent_data)
    c2pol = zeros(Float64,length(s.ofmats))
    for i in 1:length(s.ofmats)
        c2pol[i] = abs(sum(s.ofmats[i] .* [1, -1, 1, -1, 1, -1, 1, -1]))
    end
    c2pol
end
# Out:
# C2x (generic function with 1 method)

# %%
t1 =C2x(simportedqahnosubs)
t2 = C2x(simportedvpnosubs)
fig = Figure()
ax = Axis(fig[1,1]) 
lines!(ax, simportedqahnosubs.ns, t1, label = "qah")
lines!(ax, simportedvpnosubs.ns, t2, label = "vp")
axislegend(ax, position = :lt)
fig

# %%
simportedvpnosubs.ofmats[2]
# Out:
# 8-element Vector{Float64}:
#  0.8785817023723408
#  0.13776891876383543
#  0.12189883302571554
#  0.8775231137270186
#  0.8775224482564119
#  0.12189811761617507
#  0.877523113426816
#  0.1218988333248555

# %%
l
# Out:
# 1×23 DataFrame
#  Row │ J        KIVC   M        U1       U2       VP    c2ybreakingmass  n     ⋯
#      │ Float64  Bool   Float64  Float64  Float64  Bool  Float64          Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1.0  false      5.0      5.0      0.0  true              0.0      0 ⋯
#                                                               16 columns omitted

# %%
lbrokensubs = readparams(2281278)
# Out:
# 1×23 DataFrame
#  Row │ J        KIVC   M        U1       U2       VP    c2ybreakingmass  n     ⋯
#      │ Float64  Bool   Float64  Float64  Float64  Bool  Float64          Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1.0  false      5.0      5.0      0.0  true              0.0      0 ⋯
#                                                               16 columns omitted

# %% [markdown]
# ## Butterfly

# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_atlas_plotters.jl")
# Out:
# butterflyvst (generic function with 6 methods)

# %%
toτ = 0:.01:1
fig = Figure()
ax = Axis(fig[1,1],title = "Time-Butterfly", xlabel = "t/τ")
lines!(ax, [t for t in toτ], [E(t) for t in toτ], color = :green, label = "E(t)")
lines!(ax, [t for t in toτ], [B(t) for t in toτ], color = :cyan, label = "B(t)")
axislegend(ax)
fig

# %%
include("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Projects/HeavyFermion_Optics/src/mr_atlas_plotters.jl")
butterflyvst(collect(0.5:1:3.5),PID,ylims = (-1,1).*0.0015)
# Out:
# 0.5025125628140703
# 1.5075376884422111
# 2.492462311557789
# 3.4974874371859297

# %%
butterflyvst(collect(0.5:1:3.5),PID2, ylims = (-1,1).*0.0015)
# Out:
# 0.5025125628140703
# 1.5075376884422111
# 2.492462311557789
# 3.4974874371859297
