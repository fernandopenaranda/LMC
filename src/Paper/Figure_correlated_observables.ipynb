# %%
using Pkg
Pkg.activate(dirname(dirname(pwd())))   # activate MyPackage
# Pkg.instantiate()
using Revise
using LMC
using CairoMakie
# Out:
#   Activating project at `~/Documents/Work/PostdocDonosti/Packages/LMC`

# %%
using JLD2
using JLD

# %%
import Pkg; Pkg.add("JLD")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Lz4_jll ─────────── v1.10.1+0
#    Installed H5Zblosc ────────── v0.1.2
#    Installed Blosc_jll ───────── v1.21.7+0
#    Installed Blosc ───────────── v0.7.3
#    Installed OpenMPI_jll ─────── v5.0.11+0
#    Installed MPItrampoline_jll ─ v5.5.6+0
#    Installed JLD ─────────────── v0.13.5
#    Installed HDF5 ────────────── v0.17.3
#     Updating `~/Documents/Work/PostdocDonosti/Packages/LMC/Project.toml`
#   [4138dd39] + JLD v0.13.5
#     Updating `~/Documents/Work/PostdocDonosti/Packages/LMC/Manifest.toml`
#   [a74b3585] + Blosc v0.7.3
#   [c8ec2601] + H5Zblosc v0.1.2
#   [f67ccb44] + HDF5 v0.17.3
#   [4138dd39] + JLD v0.13.5
#   [3da0fdf6] + MPIPreferences v0.1.12
#   [0b7ba130] + Blosc_jll v1.21.7+0
# ⌅ [0234f1f7] + HDF5_jll v1.14.6+0
#   [e33a78d0] + Hwloc_jll v2.13.0+1
#   [5ced341a] + Lz4_jll v1.10.1+0
# ⌅ [7cb0a576] + MPICH_jll v4.3.2+0
#   [f1f71cc9] + MPItrampoline_jll v5.5.6+0
#   [9237b28f] + MicrosoftMPI_jll v10.1.4+3
#   [fe0851c0] + OpenMPI_jll v5.0.11+0
#   [458c3c95] + OpenSSL_jll v3.5.6+0
# ⌅ [02c8fc9c] + XML2_jll v2.13.9+0
#   [a65dc6b1] + Xorg_libpciaccess_jll v0.18.1+0
#   [477f73a3] + libaec_jll v1.1.6+0
#   [4af54fe1] + LazyArtifacts
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Xorg_libpciaccess_jll
#   ✓ Libmount_jll
#   ✓ Lz4_jll
#   ✓ MPIPreferences
#   ✓ libaec_jll
#   ✓ Xorg_libXau_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ LZO_jll
#   ✓ Xorg_xtrans_jll
#   ✓ MicrosoftMPI_jll
#   ✓ Hwloc_jll
#   ✓ Glib_jll
#   ✓ Xorg_libxcb_jll
#   ✓ MPItrampoline_jll
#   ✓ OpenMPI_jll
#   ✓ Blosc_jll
#   ✓ Xorg_libX11_jll
#   ✓ MPICH_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Blosc
#   ✓ FlameGraphs
#   ✓ Cairo_jll
#   ✓ HDF5_jll
#   ✓ HarfBuzz_jll
#   ✓ Pango_jll
#   ✓ Graphviz_jll
#   ✓ ProtoBuf
#   ✓ pprof_jll
#   ✓ PProf
#   ✓ HDF5
#   ✓ H5Zblosc
#   ✓ JLD
#   ✓ LMC
#   34 dependencies successfully precompiled in 27 seconds. 171 already precompiled.
#   5 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions

# %%
pdPID = 3238850
drudePID = 3285558
lmcPID = 3286797
ahePID = 3291639
spinPID = 3241713#3251898 #3241713


pdpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(pdPID)_merged_data.jld"
pdpresetpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(pdPID)_merged_presets.jld"
drudepath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(drudePID)_merged_data.jld"
drudepresetpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(drudePID)_merged_presets.jld"
lmcpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(lmcPID)_merged_data.jld"
lmcpresetpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(lmcPID)_merged_presets.jld"
spinpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(spinPID)_merged_data.jld"
spinpresetpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(spinPID)_merged_presets.jld"


ahepath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(ahePID)_merged_data.jld"
ahepresetpath = "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/$(ahePID)_merged_presets.jld"
# Out:
# "/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/3291639_merged_presets.jld"

# %%
fig = plot_phasediagrams(pdpath, pdpresetpath)
# Out:
# dim1: 500
# dim2: 501
# nalphas[1]: (501,)

# %%
fig = plot_drude(drudepath, drudepresetpath, colorrange = [-25,25],flavor_filling = 1)
# Out:
# Error encountered while load FileIO.File{FileIO.DataFormat{:JLD}, String}("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/3285558_merged_presets.jld").
#
# Fatal error:
# File size indicates /Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/3285558_merged_presets.jld cannot be a Julia data file
#
# Stacktrace:
#
#   [1] error(s::String)
#
#     @ Base ./error.jl:35
#
#   [2] jldopen(filename::String, rd::Bool, wr::Bool, cr::Bool, tr::Bool, ff::Bool; mmaparrays::Bool, compatible::Bool, compress::Bool)
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:204
#
#   [3] jldopen
#
#     @ ~/.julia/packages/JLD/Vxkax/src/JLD.jl:162 [inlined]
#
#   [4] jldopen(fname::String, mode::String; mmaparrays::Bool, compatible::Bool, compress::Bool)
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:250
#
#   [5] jldopen(fname::String, mode::String)
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:249
#
#   [6] jldopen(::JLD.var"#44#46", ::String, ::Vararg{String}; kws::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:260
#
#   [7] jldopen
#
#     @ ~/.julia/packages/JLD/Vxkax/src/JLD.jl:259 [inlined]
#
#   [8] fileio_load(f::FileIO.File{FileIO.DataFormat{:JLD}, String})
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:1328
#
#   [9] #invokelatest#2
#
#     @ ./essentials.jl:819 [inlined]
#
#  [10] invokelatest
#
#     @ ./essentials.jl:816 [inlined]
#
#  [11] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::FileIO.Formatted; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:219
#
#  [12] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:196 [inlined]
#
#  [13] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::Symbol, ::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185
#
#  [14] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185 [inlined]
#
#  [15] load(::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:113
#
#  [16] load
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:109 [inlined]
#
#  [17] aux_plot_obs(pdpath::String, pdpresetpath::String, func::Function; flavor_filling::Int64)
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:346
#
#  [18] aux_plot_obs
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:345 [inlined]
#
#  [19] plot_obs(pdpath::String, pdpresetpath::String, func::typeof(plot_drude); kws::Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol}, NamedTuple{(:colorrange, :flavor_filling), Tuple{Vector{Int64}, Int64}}})
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:331
#
#  [20] plot_drude(pdpath::String, pdpresetpath::String; kws::Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol}, NamedTuple{(:colorrange, :flavor_filling), Tuple{Vector{Int64}, Int64}}})
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:303
#
#  [21] top-level scope
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:1
#
#
#
# Stacktrace:
#
#   [1] handle_error(e::ErrorException, q::Base.PkgId, bt::Vector{Union{Ptr{Nothing}, Base.InterpreterIP}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/error_handling.jl:75
#
#   [2] handle_exceptions(exceptions::Vector{Tuple{Any, Union{Base.PkgId, Module}, Vector}}, action::String)
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/error_handling.jl:66
#
#   [3] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::FileIO.Formatted; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:228
#
#   [4] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:196 [inlined]
#
#   [5] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::Symbol, ::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185
#
#   [6] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185 [inlined]
#
#   [7] load(::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:113
#
#   [8] load
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:109 [inlined]
#
#   [9] aux_plot_obs(pdpath::String, pdpresetpath::String, func::Function; flavor_filling::Int64)
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:346
#
#  [10] aux_plot_obs
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:345 [inlined]
#
#  [11] plot_obs(pdpath::String, pdpresetpath::String, func::typeof(plot_drude); kws::Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol}, NamedTuple{(:colorrange, :flavor_filling), Tuple{Vector{Int64}, Int64}}})
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:331
#
#  [12] plot_drude(pdpath::String, pdpresetpath::String; kws::Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol}, NamedTuple{(:colorrange, :flavor_filling), Tuple{Vector{Int64}, Int64}}})
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:303
#
#  [13] top-level scope
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:1

# %%
fig = plot_lmc(lmcpath, lmcpresetpath, colorrange = [-0.1,0.1])

# %%
fig = plot_ahe(ahepath, ahepresetspath, colorrange = [-2.5,2.5])

# %%
fig = plot_lmcspin(spinpath, spinpresetpath, colorrange = [-0.04,0.04])

# %%
using JLD2
ppd = load(pdpresetpath)
pddata = load(pdpath)
vals, vals2 = ppd["presets"]
_, pdpresets = vals
_, first_value = first(pddata["merged"])
keylist = keys(first_value)
Ezs = []
muss = []
count = 1
for (path, d) in pddata["merged"]
    Ez = d["Ezs"][1]
    mus = d["mus"][1]
    push!(Ezs, Ez)
    push!(muss, mus)
end
νlist = first_value["nu_list"];

# %%
function aux_bands(νval, Ezval)

    idxnu = argmin(abs.(νlist .- νval))
    idxEz = argmin(abs.(Ezs .- Ezval))
    spinfull_plotbandsanddos(pdpresets.N, pdpresets.p, νlist[idxnu], 
    muss[idxEz][idxnu], Ezs[idxEz], collect(-10:0.1:10), points = 100, evals = 10)
end
# Out:
# aux_bands (generic function with 1 method)

# %%
aux_bands(-0.25, 3)

# %%
aux_bands(-0.1, 3)

# %% [markdown]
# ## Plot

# %%
function lat_figure4(pdpath, pdpresetpath, lmcpath, lmcpresetpath, ahepath, ahepresetpath; fontsizetheme = 15)
    with_theme(merge(theme_latexfonts(), Theme(fontsize = fontsizetheme))) do #
        Figure4(pdpath, pdpresetpath, lmcpath, lmcpresetpath, ahepath, ahepresetpath, fontsize = fontsizetheme)   
    end
end

function Figure4(pdpath, pdpresetpath, lmcpath, lmcpresetpath, ahepath, ahepresetpath; fontsize = 8)
    fig = Figure(size = (600, 600))
    ga = fig[1:2,1] = GridLayout()
    ax1 = Axis(ga[1,1], xlabel = L"$\nu\text{ [}10^{12}\text{ cm}^{-2}\text{]}$", ylabel = L"$E_z \text{ [meV]}$", xlabelsize = fontsize +2, ylabelsize = fontsize +2)
    gb =fig[1,2] =  GridLayout()
    ax2 = Axis(gb[1,1], xlabel = L"$\nu\text{ [}10^{12}\text{ cm}^{-2}\text{]}$", ylabel = L"$E_z \text{ [meV]}$", xlabelsize = fontsize +2, ylabelsize = fontsize +2)
    ax3 = Axis(ga[2,1], xlabel = L"$\nu\text{ [}10^{12}\text{ cm}^{-2}\text{]}$", ylabel = L"$E_z \text{ [meV]}$", xlabelsize = fontsize +2, ylabelsize = fontsize +2)
    gd = fig[2,2] = GridLayout()
    ax4 = Axis(gd[1,1], xlabel = L"$\nu\text{ [}10^{12}\text{ cm}^{-2}\text{]}$", ylabel = L"$E_z \text{ [meV]}$", xlabelsize = fontsize +2, ylabelsize = fontsize +2)



    #_________________________________________
    # plot_phasediagrams(ax1, pdpath, pdpresetpath; colorlist = missing, axisleg = false)
    ylims!(ax1, -10,10)
    ax1.xticks = ([-0.5,0,0.5])
    #_________________________________________
    hm = plot_drude(ax2, drudepath, drudepresetpath, colorrange = [0,25])
    cb = Colorbar(gb[1,2], hm, label = "σxx [e²/h]", vertical = true,  
        ticks = ([0,25], ["0", "25"]), labelpadding = -15)
    ylims!(ax2,-10,10)
    ax2.xticks = ([-0.5,0,0.5])

    #_________________________________________
    # hm = plot_lmc(ax3, ahepath, ahepresetpath, colorrange = [-2, 2], absolute = true)
    cb = Colorbar(ga[2,2], hm, label = "|σxy| [e²/h]", vertical = true,  
        ticks = ([-2,0,2], ["-2","0","2"]), labelpadding = -15)
    ylims!(ax3,-10,10)
    # xlims!(ax3,-0.25,0.25)
    # ax3.xticks = ([-0.5,0,0.5])
    # xlims!(ax, -0.25,0.25)
    #_________________________________________
    # hm = plot_lmc(ax4, lmcpath, lmcpresetpath, colorrange = [-0.1,0.1], absolute = true)
    cb = Colorbar(gd[1,2], hm, label = L"$σxxx| [1/T e²/h]$", labelsize = fontsize +1, vertical = true, labelpadding = -15,
        ticks = ([-0.1,0,0.1], ["-0.1","0","0.1"]), ticklabelpad = 2, ticklabelsize = fontsize, ticksize = 4)
    ylims!(ax4,-10,10)
    ax4.xticks = ([-0.5,0,0.5])

    scatter!(ax1, [NaN], [NaN], color = :gray, label = "Symmetric", marker = :rect, markersize = fontsize)
    scatter!(ax1, [NaN], [NaN], color = :blue, label = "SPHM", marker = :rect, markersize = fontsize)
    scatter!(ax1, [NaN], [NaN], color = :purple, label = "VPHM", marker = :rect, markersize = fontsize)
    scatter!(ax1, [NaN], [NaN], color = :lightblue, label = "QM", marker = :rect, markersize = fontsize)
    
    axislegend(ax1, position = :ct, orientation = :horizontal, labelsize = fontsize-3,
                titlesize = fontsize, patchlabelgap = 0, padding = (2,2,2,2), patchsize = (fontsize, fontsize), colgap = 3,
                margin = (0, 0, 6, 0) )

    colgap!(gb, 1)
    colgap!(ga, 1)
    colgap!(gd, 1)
#_______________________________________________________________________________________
#_________________________________________ LEGEND
# colorlist = [:purple, :gray, :blue, :lightblue]
# markers = [ MarkerElement(color = colorlist[2], marker = :rect, markersize = fontsize),
# MarkerElement(color = colorlist[4],   marker = :rect, markersize = fontsize), 
# MarkerElement(color = colorlist[3],   marker = :rect, markersize = fontsize) ,
# MarkerElement(color = colorlist[1],   marker = :rect, markersize = fontsize)]
    # labels = ["Symmetric", "QM/3QM", "SPHM", "VPHM"]

    # Legend(
    #     fig[0, 1:1],
    #     markers,
    #     labels,
    #     orientation = :horizontal,
    #     framevisible = true,
    #     labelsize = fontsize - 2,
    #     framesize = 0.5,
    #     fontsize = fontsize -2 ,
    #     framecolor = :black,
    #     padding = (0, 0, 1, 1),
    #     patchsize = (18, 18),
    #     colgap = 1,
    #     rowgap = -100, 
    #     patchlabelgap = 0,
    #     tellwidth = true
    # )
#_______________________________________________________________________________________

    hideydecorations!(ax2, grid = false)
    hideydecorations!(ax4, grid = false)
    hidexdecorations!(ax1, grid = false)
    hidexdecorations!(ax2, grid = false)
    colgap!(fig.layout, -5)
    Label(fig[1, 1, TopLeft()], "a)",
        fontsize = fontsize,
        padding = (0, 30, -10, 0),
        halign = :right)

    Label(fig[1, 2, TopLeft()], "b)",
    fontsize = fontsize,
    padding = (0, 5, -10, 0),
    halign = :right)

    Label(fig[2, 1, TopLeft()], "c)",
    fontsize = fontsize,
    padding = (0, 30, -30, 0),
    halign = :right)
    Label(fig[2, 2, TopLeft()], "d)",
    fontsize = fontsize,
    padding = (0, 5, -30, 0),
    halign = :right)
    fig
end
# Out:
# Figure4 (generic function with 1 method)

# %%
fig4 = lat_figure4(pdpath, pdpresetpath, lmcpath, lmcpresetpath, ahepath, ahepresetpath, fontsizetheme = 14)
# Out:
# Error encountered while load FileIO.File{FileIO.DataFormat{:JLD}, String}("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/3285558_merged_presets.jld").
#
# Fatal error:
# File size indicates /Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/ClusterDATA/LMC/3285558_merged_presets.jld cannot be a Julia data file
#
# Stacktrace:
#
#   [1] error(s::String)
#
#     @ Base ./error.jl:35
#
#   [2] jldopen(filename::String, rd::Bool, wr::Bool, cr::Bool, tr::Bool, ff::Bool; mmaparrays::Bool, compatible::Bool, compress::Bool)
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:204
#
#   [3] jldopen
#
#     @ ~/.julia/packages/JLD/Vxkax/src/JLD.jl:162 [inlined]
#
#   [4] jldopen(fname::String, mode::String; mmaparrays::Bool, compatible::Bool, compress::Bool)
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:250
#
#   [5] jldopen(fname::String, mode::String)
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:249
#
#   [6] jldopen(::JLD.var"#44#46", ::String, ::Vararg{String}; kws::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:260
#
#   [7] jldopen
#
#     @ ~/.julia/packages/JLD/Vxkax/src/JLD.jl:259 [inlined]
#
#   [8] fileio_load(f::FileIO.File{FileIO.DataFormat{:JLD}, String})
#
#     @ JLD ~/.julia/packages/JLD/Vxkax/src/JLD.jl:1328
#
#   [9] #invokelatest#2
#
#     @ ./essentials.jl:819 [inlined]
#
#  [10] invokelatest
#
#     @ ./essentials.jl:816 [inlined]
#
#  [11] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::FileIO.Formatted; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:219
#
#  [12] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:196 [inlined]
#
#  [13] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::Symbol, ::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185
#
#  [14] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185 [inlined]
#
#  [15] load(::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:113
#
#  [16] load
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:109 [inlined]
#
#  [17] aux_plot_obs(pdpath::String, pdpresetpath::String, func::Function; flavor_filling::Int64)
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:346
#
#  [18] aux_plot_obs
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:345 [inlined]
#
#  [19] plot_obs(ax::Axis, pdpath::String, pdpresetpath::String, func::typeof(plot_drude); flavor_filling::Int64, kws::Base.Pairs{Symbol, Vector{Int64}, Tuple{Symbol}, NamedTuple{(:colorrange,), Tuple{Vector{Int64}}}})
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:336
#
#  [20] plot_obs
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:335 [inlined]
#
#  [21] #plot_drude#26
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:306 [inlined]
#
#  [22] Figure4(pdpath::String, pdpresetpath::String, lmcpath::String, lmcpresetpath::String, ahepath::String, ahepresetpath::String; fontsize::Int64)
#
#     @ Main ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:25
#
#  [23] Figure4
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:8 [inlined]
#
#  [24] #31
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:4 [inlined]
#
#  [25] (::Makie.var"#279#280"{Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, var"#31#32"{Int64, String, String, String, String, String, String}, Attributes})()
#
#     @ Makie ~/.julia/packages/Makie/VRavR/src/theming.jl:227
#
#  [26] lock(f::Makie.var"#279#280"{Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, var"#31#32"{Int64, String, String, String, String, String, String}, Attributes}, l::ReentrantLock)
#
#     @ Base ./lock.jl:229
#
#  [27] #with_theme#278
#
#     @ ~/.julia/packages/Makie/VRavR/src/theming.jl:223 [inlined]
#
#  [28] with_theme
#
#     @ ~/.julia/packages/Makie/VRavR/src/theming.jl:222 [inlined]
#
#  [29] #lat_figure4#30
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:3 [inlined]
#
#  [30] top-level scope
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:1
#
#
#
# Stacktrace:
#
#   [1] handle_error(e::ErrorException, q::Base.PkgId, bt::Vector{Union{Ptr{Nothing}, Base.InterpreterIP}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/error_handling.jl:75
#
#   [2] handle_exceptions(exceptions::Vector{Tuple{Any, Union{Base.PkgId, Module}, Vector}}, action::String)
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/error_handling.jl:66
#
#   [3] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::FileIO.Formatted; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:228
#
#   [4] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:196 [inlined]
#
#   [5] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::Symbol, ::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185
#
#   [6] action
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:185 [inlined]
#
#   [7] load(::String; options::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ FileIO ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:113
#
#   [8] load
#
#     @ ~/.julia/packages/FileIO/EI2b8/src/loadsave.jl:109 [inlined]
#
#   [9] aux_plot_obs(pdpath::String, pdpresetpath::String, func::Function; flavor_filling::Int64)
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:346
#
#  [10] aux_plot_obs
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:345 [inlined]
#
#  [11] plot_obs(ax::Axis, pdpath::String, pdpresetpath::String, func::typeof(plot_drude); flavor_filling::Int64, kws::Base.Pairs{Symbol, Vector{Int64}, Tuple{Symbol}, NamedTuple{(:colorrange,), Tuple{Vector{Int64}}}})
#
#     @ LMC_CairoMakieExt ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:336
#
#  [12] plot_obs
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:335 [inlined]
#
#  [13] #plot_drude#26
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/model/rhombohedral/plotters.jl:306 [inlined]
#
#  [14] Figure4(pdpath::String, pdpresetpath::String, lmcpath::String, lmcpresetpath::String, ahepath::String, ahepresetpath::String; fontsize::Int64)
#
#     @ Main ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:25
#
#  [15] Figure4
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:8 [inlined]
#
#  [16] #31
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:4 [inlined]
#
#  [17] (::Makie.var"#279#280"{Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, var"#31#32"{Int64, String, String, String, String, String, String}, Attributes})()
#
#     @ Makie ~/.julia/packages/Makie/VRavR/src/theming.jl:227
#
#  [18] lock(f::Makie.var"#279#280"{Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, var"#31#32"{Int64, String, String, String, String, String, String}, Attributes}, l::ReentrantLock)
#
#     @ Base ./lock.jl:229
#
#  [19] #with_theme#278
#
#     @ ~/.julia/packages/Makie/VRavR/src/theming.jl:223 [inlined]
#
#  [20] with_theme
#
#     @ ~/.julia/packages/Makie/VRavR/src/theming.jl:222 [inlined]
#
#  [21] #lat_figure4#30
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:3 [inlined]
#
#  [22] top-level scope
#
#     @ ~/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figure_correlated_observables.ipynb:1

# %%
v = "v2"
save("/Users/fernandopenaranda/Documents/Work/PostdocDonosti/Packages/LMC/src/Paper/Figures/Figure4$(v).pdf", fig4)
# Out:
# CairoMakie.Screen{PDF}
